# %% [markdown]
# # GPT Prompt 생성
#
#
# > **주제: 한국 보험 약관의 해석 및 비판적 분석** <br/><br/>
# Topic: Interpretation and critical analysis of Korean insurance terms

# %% [markdown]
# ## Step 1: 약관 원문 '심층 이해' (CoT 집중, RAG 활용)
#
# ### 이 단계의 목표: 분석 대상 약관 문구를 정확히 이해하는 것. RAG를 통해 관련 외부 정보를 참고하며 이해의 깊이를 더해.
# ### 수정 내용:
# 주어진 약관 문구를 읽을 때, 동시에 벡터 스토어에서 해당 문구와 관련된 정보를 검색. (Langchain Retriever 사용)
#
# 검색된 관련 정보(예: 분쟁 사례, 관련 법규 조항)를 약관 문구와 함께 GPT 프롬프트에 넣어줘.
#
# GPT는 약관 문구와 검색된 외부 정보를 모두 참고해 약관의 의미 심층적 파악 가능
#
# CoT처럼 단계별 이해 과정을 프롬프트에 포함시켜서 정확한 이해 유도

# %% [markdown]
# ### basic setting

# %% [markdown]
# #### library load

# %%
# !pip install -U langchain-community langchain-openai chromadb PyMuPDF langchain-chroma
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (0.3.24)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.11/dist-packages (0.3.19)
# Requirement already satisfied: chromadb in /usr/local/lib/python3.11/dist-packages (1.0.12)
# Requirement already satisfied: PyMuPDF in /usr/local/lib/python3.11/dist-packages (1.26.0)
# Requirement already satisfied: langchain-chroma in /usr/local/lib/python3.11/dist-packages (0.2.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.63)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.42)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /usr/local/lib/python3.11/dist-packages (from langchain-openai) (1.81.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.11/dist-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.11/dist-packages (from chromadb) (2.11.4)
# Requirement already satisfied: fastapi==0.115.9 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.3)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.13.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.33.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.11/dist-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.15.3)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.23.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.4.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.25->langchain-community) (0.3.8)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain-community) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.13.2->chromadb) (0.31.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-community) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)

# %%
import os
import json
import re
# Google Drive 마운트 필요
from google.colab import drive
from google.colab import userdata
import time
drive.mount('/content/drive')
from collections import defaultdict
# Out:
# Mounted at /content/drive

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings # <-- 이 임포트 라인 사용
from langchain_openai import ChatOpenAI     # <-- 이 임포트 라인 사용
from langchain_chroma import Chroma
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from langchain_core.documents import Document

# %% [markdown]
# #### setting openai-api-key and model

# %%
# --- OpenAI API 키 설정 (userdata로 가져와 os.environ에 설정) ---
print("OpenAI API 키 설정 확인 중 (userdata 사용)...")
# Colab '비밀' 저장소에서 'OPENAI_API_KEY' 값을 가져옵니다.
from google.colab import userdata
openai_api_key = userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = xx

if openai_api_key is None:
    print("!!! 오류: Colab '비밀'에서 'OPENAI_API_KEY'를 가져오지 못했습니다. !!!")
    print("Colab 왼쪽의 자물쇠 아이콘(비밀)에서 'OPENAI_API_KEY' 이름으로 키가 설정되었는지 확인해주세요.")
    # API 키 없이는 임베딩 모델 로드 및 GPT 모델 호출이 불가능하므로 관련 객체는 None
    embeddings = None
    llm = None
    rag_vectorstore = None # 벡터 스토어 로드 불가
else:
    # userdata로 가져온 키 값을 os.environ 환경 변수에 설정해 줍니다. <-- 이 부분이 핵심!
    os.environ['OPENAI_API_KEY'] = openai_api_key
    print("'OPENAI_API_KEY' 환경 변수 설정 완료 (userdata 사용).")

    # 이제 Langchain 모델들이 이 환경 변수에서 키를 자동으로 읽어갑니다.

    # 임베딩 모델 로드 (벡터 스토어 로드 및 RAG 검색 시 필요)
    try:
        embeddings = OpenAIEmbeddings(model="text-embedding-3-small") # 환경 변수 사용
        print("OpenAI 임베딩 모델 준비 완료.")
    except Exception as e:
        print(f"!!! 오류: 임베딩 모델 로드 오류: {e} !!!")
        print("환경 변수에 설정된 API 키가 유효한지, 모델 이름이 올바른지 확인하세요.")
        embeddings = None

    # GPT 모델 준비 (심층 이해 분석 및 CoT 추론 시 필요)
    try:
        llm = ChatOpenAI(model="gpt-4o-2024-05-13", temperature=0.0) # 환경 변수 사용
        print(f"GPT 모델 준비 완료: {llm.model_name}")
    except Exception as e:
        print(f"!!! 오류: GPT 모델 로드 오류: {e} !!!")
        print("환경 변수에 설정된 API 키가 유효한지, 모델 이름이 올바른지 확인하세요.")
        llm = None

    # 임베딩 모델 또는 LLM 로드 실패 시 rag_vectorstore 로드 불가
    if embeddings is None or llm is None:
         rag_vectorstore = None # 아래 벡터 스토어 로드 로직이 오류나지 않도록 None으로 설정
    # else: rag_vectorstore는 아래 로드 로직에서 설정
# Out:
# OpenAI API 키 설정 확인 중 (userdata 사용)...
# 'OPENAI_API_KEY' 환경 변수 설정 완료 (userdata 사용).
# OpenAI 임베딩 모델 준비 완료.
# GPT 모델 준비 완료: gpt-4o-2024-05-13

# %%
# !pip install -U langchain-huggingface
# Out:
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.2.0-py3-none-any.whl.metadata (941 bytes)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in /usr/local/lib/python3.11/dist-packages (from langchain-huggingface) (0.3.63)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from langchain-huggingface) (0.21.1)
# Requirement already satisfied: transformers>=4.39.0 in /usr/local/lib/python3.11/dist-packages (from langchain-huggingface) (4.52.4)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from langchain-huggingface) (4.1.0)
# Requirement already satisfied: huggingface-hub>=0.30.2 in /usr/local/lib/python3.11/dist-packages (from langchain-huggingface) (0.31.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.13.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.3.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.33)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.11.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.15.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (11.2.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.39.0->langchain-huggingface) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.39.0->langchain-huggingface) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.39.0->langchain-huggingface) (0.5.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2025.4.26)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (3.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.126->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.3.1)
# Downloading langchain_huggingface-0.2.0-py3-none-any.whl (27 kB)
# Installing collected packages: langchain-huggingface
# Successfully installed langchain-huggingface-0.2.0

# %%
from langchain_huggingface import HuggingFaceEndpoint


# Hugging Face API 토큰 필요 (https://huggingface.co/settings/tokens 에서 생성)
HUGGINGFACEHUB_API_TOKEN = "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"

llm = HuggingFaceEndpoint(
    repo_id="HuggingFaceH4/zephyr-7b-beta",  # 무료 사용 가능한 공개 모델
    huggingfacehub_api_token="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",  # 본인의 HF 토큰
    temperature=0.7,
    max_new_tokens=512
)

# %%
# !pip install bitsandbytes accelerate transformers
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.46.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.31.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from langchain.llms import HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch

model_name = "HuggingFaceH4/zephyr-7b-beta"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    load_in_4bit=True,
    torch_dtype=torch.float16
)

llm = pipeline("text-generation", model=model, tokenizer=tokenizer)
# LangChain용 LLM 래퍼 생성
llm_langchain = HuggingFacePipeline(pipeline=llm)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Device set to use cuda:0
# <ipython-input-21-cb064d44c76f>:21: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm_langchain = HuggingFacePipeline(pipeline=llm)

# %%
# !pip install -U bitsandbytes accelerate transformers
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.46.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.31.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch

model_name = "HuggingFaceH4/zephyr-7b-beta"

# 토크나이저 로드
tokenizer = AutoTokenizer.from_pretrained(model_name)

# 4비트로 모델 로드
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",                 # 자동 분산
    load_in_4bit=True,                # 4비트 로딩
    torch_dtype=torch.float16         # 권장 dtype
)

# pipeline 생성 (device 명시하면 안 됨)
llm = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
import openai
client = openai.OpenAI(api_key = userdata.get('OPENAI_API_KEY'))

# %% [markdown]
# #### check vector store and number of chunks

# %%
# --- 벡터 스토어 영구 저장 경로 지정 --- (이전 코드와 동일)
PERSIST_DIRECTORY = '/content/drive/MyDrive/PROJECT/cn_api_project/chroma_db' # 예시 경로

# --- 벡터 스토어 로드 (최신 Chroma 클래스 사용) ---
rag_vectorstore = None # 초기화
# 임베딩 모델이 성공적으로 로드되었고 (API 키가 설정되었고) 저장 경로가 존재하면 로드 시도
if embeddings is not None and os.path.exists(PERSIST_DIRECTORY):
    print(f"\n--- 벡터 스토어 로드 중: '{PERSIST_DIRECTORY}' ---")
    try:
        # 영구 저장된 ChromaDB에서 벡터 스토어 로드 (최신 Chroma 클래스 사용)
        # 최신 Chroma 클래스도 로드 시 persist_directory와 embedding_function을 받습니다.
        rag_vectorstore = Chroma(persist_directory=PERSIST_DIRECTORY, embedding_function=embeddings)
        print("벡터 스토어 로드 완료.")
        print(f"로드된 청크 개수: {rag_vectorstore._collection.count()}") # 로드된 청크 개수 확인!

    except Exception as e:
        print(f"!!! 오류: 벡터 스토어 로드 중 오류 발생 !!!")
        print(f"오류 내용: {e}")
        print(f"경로 확인: '{PERSIST_DIRECTORY}'에 파일 있는지, 로드 시 사용한 임베딩 모델이 올바른지 확인하세요.")
        rag_vectorstore = None
else:
    if embeddings is None:
        print("\n!!! 벡터 스토어 로드 불가: 임베딩 모델 로드 오류 (API 키 확인 필요). !!!")
    elif not os.path.exists(PERSIST_DIRECTORY):
         print(f"\n!!! 벡터 스토어 로드 불가: 저장 폴더를 찾을 수 없습니다 - '{PERSIST_DIRECTORY}' !!!")
         print("첫 번째 노트북에서 Step 0을 실행하여 벡터 스토어를 해당 경로에 저장했는지 확인해주세요.")
# Out:
# --- 벡터 스토어 로드 중: '/content/drive/MyDrive/PROJECT/cn_api_project/chroma_db' ---
# 벡터 스토어 로드 완료.
# 로드된 청크 개수: 37249

# %% [markdown]
# ### 심층 이해 과정

# %% [markdown]
# #### 심층 이해를 위한 프롬프트 템플릿

# %% [markdown]
# > deep_understanding_template

# %%
# --- 심층 이해를 위한 프롬프트 템플릿 (CoT + RAG Context 포함) --- (이전 코드와 동일)
deep_understanding_template = """
## 역할: 보험 약관 심층 분석 전문가 (RAG 기반 분석자)

## 분석 목표:
- 아래 **[분석 대상 약관 문구]**와 **[참고 자료]**를 기반으로 해당 조항의 의미, 목적, 실제 적용 맥락을 깊이 있게 해석해 주세요.
- 모호하거나 법적 쟁점이 될 수 있는 요소를 명확히 밝히고, 관련된 유사 표현, 해석 방식, 소비자 민원 또는 사례 기반으로 조항의 의미를 깊이 있게 해석해 주세요.


[분석 대상 약관 문구]:
{clause_text}

[참고 자료]:
{rag_context}

---

## 분석 지침:

1. **문구 정밀 분석:**
   - 각 단어, 문장 구조, 조건 표현, 예외 조항 등을 세밀하게 분석합니다.
   - 문구의 표면적 의미뿐 아니라 실질적인 적용 범위를 유추해 주세요.

2. **RAG 연결:**
   - [참고 자료]에 있는 유사 약관, 분쟁 사례, 법령 조항 중 약관 해석에 직접적으로 기여하는 내용을 우선 정리합니다.
   - 어떤 자료가 어떤 식으로 해석에 도움을 주는지 명확히 설명해 주세요.

### 3. 실제 적용 시나리오 기반 추론 (Chain of Thought)
- 다음 단계별로 사고 과정을 전개하세요:
  - Step 1: 해당 조항이 적용되는 전형적인 상황
  - Step 2: 적용 여부 판단 조건
  - Step 3: 보험자 vs 계약자의 책임 귀속
  - Step 4: 모호성 또는 분쟁 발생 가능성

4. **핵심 정리 (보험 전문가 관점):**
   - 이 조항의 목적, 핵심 쟁점, 소비자 보호 또는 보험자의 책임 측면에서 반드시 유의해야 할 점을 정리합니다.
   - 오해 소지가 있는 부분, 반드시 명확히 이해해야 하는 요소도 명시해 주세요.


5. **분류 및 메타 정보 출력**

6. **출력 형식 (Markdown):**
   다음과 같이 구분하여 출력해 주세요:

```markdown
# 약관 문구 심층 이해 분석

## 1. 분석 대상 약관 문구

{clause_text}

## 2. RAG 참고 자료 요약 및 연결

- **자료1 - 유사 약관 조항:** [조항 내용 요약 + 연결된 해석]
- **자료2 - 소비자 민원 사례:** [어떤 민원에서 어떤 쟁점으로 다뤄졌는지]
- **자료3 - 법령 또는 기준:** [어떤 법적 기준이 적용되며 이 조항과의 연결점]
...

## 3. 문구의 구조적 분석 및 해석

- 각 문장 요소 분석
- 조건 해석 및 의도 추론
...

## 4. 실제 적용 시나리오 및 단계별 추론 (CoT)

- Step 1: 이 조항이 적용될 수 있는 전형적인 상황
- Step 2: 이 조항이 불명확하게 적용될 수 있는 예외적 상황
...

## 5. 전문가 관점 핵심 요약

- 조항의 주요 목적:
- 소비자/보험자가 주의해야 할 핵심 요소:
- 자주 발생하는 오해 및 분쟁 포인트:
...

## 6. 분석 메타 정보

- 약관 요약 위치 (소제목):
- 문서 출처:
- 문제 유형: ["문구 모호성", "보장 조건 불명확", "책임 범위 불명확", "적용 예외 과도", "법령과 불일치"]
"""

# %% [markdown]
# #### load_summary_text 함수

# %%
def load_summary_text(summary_file_path):
    summary_clause_text = ""
    print(f"\n--- 분석 대상 약관 원문 전체 텍스트 로드 중: '{summary_file_path}' ---")
    try:
        if os.path.exists(summary_file_path):
            with open(summary_file_path, 'r', encoding='utf-8') as f:
                summary_clause_text = f.read()
            print("약관 원문 전체 텍스트 로드 완료.")
            print(f"로드된 텍스트 길이: {len(summary_clause_text)} 문자.")
        else:
            print(f"!!! 오류: 약관 원문 전체 텍스트 파일을 찾을 수 없습니다 - '{summary_file_path}' !!!")
            print("경로와 파일 이름을 확인하세요.")
    except Exception as e:
        print(f"!!! 오류: 약관 원문 전체 텍스트 로드 중 예외 발생: {e} !!!")
    return summary_clause_text

# %% [markdown]
# #### analyze_clause_deeply 함수
#
#
# > 특정 약관 문구를 RAG 검색 및 CoT를 활용하여 심층적으로 이해하고 분석

# %%
def analyze_clause_deeply(clause_text, rag_vectorstore, llm, num_rag_results=5, model="gpt-4o-2024-05-13"):

    if llm is None:
        print("!!! 오류: GPT 모델(llm)이 로드되지 않아 분석을 진행할 수 없습니다. API 키 설정 확인 필요. !!!")
        return "분석 실패: GPT 모델 오류"
        # RAG 검색은 rag_vectorstore가 None이 아니면 시도합니다.
        rag_context_text = "참고 자료 없음 (벡터 스토어 로드 실패)."
    if rag_vectorstore is not None:
        print("\n--- RAG 검색 시작 ---")
        try:
            retriever = rag_vectorstore.as_retriever(search_kwargs={"k": num_rag_results})
            retrieved_docs = retriever.invoke(clause_text)
            rag_context_text = "\n----\n".join([
                f"출처: {doc.metadata.get('source', '알 수 없음')}, 페이지: {doc.metadata.get('page', '알 수 없음')}\n{doc.page_content}"
                for doc in retrieved_docs
            ])
            print(f"RAG 검색 완료. 총 {len(retrieved_docs)}개의 참고 자료 확보.")
        except Exception as e:
            print(f"!!! 오류: RAG 검색 중 오류 발생: {e} !!!")
            print("벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.")
            rag_context_text = "오류 발생: 참고 자료 검색 실패."

    # GPT 프롬프트 메시지 구성 (약관 문구 + RAG Context 포함)
    message = deep_understanding_template.format(
        clause_text=clause_text,
        rag_context=rag_context_text if rag_context_text else "참고 자료 없음."
    )

    # GPT 모델 호출 (심층 이해 분석 및 CoT 추론)
    print("\n--- GPT 심층 이해 분석 시작 (CoT 유도) ---")
    try:
        messages = [{"role": "user", "content": message}]
        response = llm.invoke(messages)
        response_text = response.content

        print("\n--- GPT 심층 이해 분석 완료 ---")
        return response_text

    except Exception as e:
        print(f"!!! 오류: GPT 심층 이해 분석 중 오류 발생: {e} !!!")
        print("GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.")
        return f"분석 실패: GPT 오류 - {e}"

# %% [markdown]
# ### 일단 요약본 하나만 심층분석

# %%
summary_file_path = '/content/drive/MyDrive/PROJECT/cn_api_project/data/보험약관/summary/삼성화재_반려묘보험_애니펫_summary.txt'

# %%
summary_text = load_summary_text(summary_file_path)
clause_list = summary_text.split("\n\n")  # 또는 '\n제' 등 조항 기준
# Out:
# --- 분석 대상 약관 원문 전체 텍스트 로드 중: '/content/drive/MyDrive/PROJECT/cn_api_project/data/보험약관/summary/삼성화재_반려묘보험_애니펫_summary.txt' ---
# 약관 원문 전체 텍스트 로드 완료.
# 로드된 텍스트 길이: 71103 문자.

# %%
summary_clause_text = "" # 변수 초기화
print(f"\n--- 분석 대상 약관 원문 전체 텍스트 로드 중: '{summary_file_path}' ---")
try: # 파일 존재 확인
    if os.path.exists(summary_file_path):
    # 파일 읽기 모드('r', read)로 열고 전체 내용 읽기
        with open(summary_file_path, 'r', encoding='utf-8') as f:
            summary_clause_text = f.read()
        print("약관 원문 전체 텍스트 로드 완료.")
        print(f"로드된 텍스트 길이: {len(summary_clause_text)} 문자.")
    else:
        print(f"!!! 오류: 약관 원문 전체 텍스트 파일을 찾을 수 없습니다 - '{summary_file_path}' !!!")
        print("Google Drive 마운트 상태와 경로를 확인해주세요.")
        summary_clause_text = "" # 파일 없으면 빈 문자열

except Exception as e:
    print(f"!!! 오류: 약관 원문 전체 텍스트 로드 중 오류 발생: {e} !!!")
    summary_clause_text = "" # 로드 실패 시 빈 문자열
# Out:
# --- 분석 대상 약관 원문 전체 텍스트 로드 중: '/content/drive/MyDrive/PROJECT/cn_api_project/data/보험약관/summary/삼성화재_반려묘보험_애니펫_summary.txt' ---
# 약관 원문 전체 텍스트 로드 완료.
# 로드된 텍스트 길이: 71103 문자.

# %% [markdown]
# #### split_text_into_chunks 정의
# > text, chunk_size = 2000, chunk_overlap = 200

# %%
def split_text_into_chunks(text, chunk_size=1000, chunk_overlap=200):
    text_splitter = RecursiveCharacterTextSplitter(
        separators=["\n\n", "\n", ".", " "],
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
    )
    chunks = text_splitter.split_text(text)
    print(f"총 {len(chunks)}개의 청크로 분할됨. (chunk_size={chunk_size}, overlap={chunk_overlap})")
    return chunks

# %% [markdown]
# #### analyze_chunks_individually
# > text_chunks, rag_vectorstore, llm

# %%
def analyze_chunks_individually(text_chunks, rag_vectorstore, llm):
    all_results = []

    for i, chunk in enumerate(text_chunks):
        print(f"\n--- [{i+1}/{len(text_chunks)}] 번째 청크 분석 시작 ---")
        result = analyze_clause_deeply(chunk, rag_vectorstore, llm)
        all_results.append(f"🔹 [청크 {i+1} 분석 결과]\n{result}\n")

    return "\n\n".join(all_results)

# %% [markdown]
# #### Huggingface

# %%
# !pip install -U bitsandbytes accelerate transformers
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.2)
# Collecting transformers
#   Downloading transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.31.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 13.1 MB/s eta 0:00:00
# Downloading transformers-4.52.4-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 125.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 61.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 56.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, transformers, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.2
#     Uninstalling transformers-4.52.2:
#       Successfully uninstalled transformers-4.52.2
# Successfully installed bitsandbytes-0.46.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 transformers-4.52.4

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch

model_name = "HuggingFaceH4/zephyr-7b-beta"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    load_in_4bit=True,
    torch_dtype=torch.float16
)

llm = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/638 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model-00004-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00001-of-00008.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00003-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00005-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00002-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/816M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Device set to use cuda:0

# %% [markdown]
# #### 코드 실행

# %% [markdown]
# > 변수 정의

# %%
# --- 벡터 스토어 영구 저장 경로 지정 --- (이전 코드와 동일)
PERSIST_DIRECTORY = '/content/drive/MyDrive/PROJECT/cn_api_project/chroma_db' # 예시 경로

# --- 벡터 스토어 로드 (최신 Chroma 클래스 사용) ---
rag_vectorstore = None # 초기화
# 임베딩 모델이 성공적으로 로드되었고 (API 키가 설정되었고) 저장 경로가 존재하면 로드 시도
if embeddings is not None and os.path.exists(PERSIST_DIRECTORY):
    print(f"\n--- 벡터 스토어 로드 중: '{PERSIST_DIRECTORY}' ---")
    try:
        # 영구 저장된 ChromaDB에서 벡터 스토어 로드 (최신 Chroma 클래스 사용)
        # 최신 Chroma 클래스도 로드 시 persist_directory와 embedding_function을 받습니다.
        rag_vectorstore = Chroma(persist_directory=PERSIST_DIRECTORY, embedding_function=embeddings)
        print("벡터 스토어 로드 완료.")
        print(f"로드된 청크 개수: {rag_vectorstore._collection.count()}") # 로드된 청크 개수 확인!

    except Exception as e:
        print(f"!!! 오류: 벡터 스토어 로드 중 오류 발생 !!!")
        print(f"오류 내용: {e}")
        print(f"경로 확인: '{PERSIST_DIRECTORY}'에 파일 있는지, 로드 시 사용한 임베딩 모델이 올바른지 확인하세요.")
        rag_vectorstore = None
else:
    if embeddings is None:
        print("\n!!! 벡터 스토어 로드 불가: 임베딩 모델 로드 오류 (API 키 확인 필요). !!!")
    elif not os.path.exists(PERSIST_DIRECTORY):
         print(f"\n!!! 벡터 스토어 로드 불가: 저장 폴더를 찾을 수 없습니다 - '{PERSIST_DIRECTORY}' !!!")
         print("첫 번째 노트북에서 Step 0을 실행하여 벡터 스토어를 해당 경로에 저장했는지 확인해주세요.")




 # 1. 텍스트 로딩
summary_clause_text = load_summary_text(summary_file_path)

# 2. 청크로 분할
text_chunks = split_text_into_chunks(summary_clause_text, chunk_size=2000)

# 3. GPT + RAG로 하나씩 분석
final_summary = analyze_chunks_individually(text_chunks, rag_vectorstore, llm)


# 4. 결과 출력 또는 저장
print("\n===== 전체 분석 결과 요약 =====\n")
print(final_summary[:1000])
# Out:
# --- 벡터 스토어 로드 중: '/content/drive/MyDrive/PROJECT/cn_api_project/chroma_db' ---
# 벡터 스토어 로드 완료.
# 로드된 청크 개수: 37249
#
# --- 분석 대상 약관 원문 전체 텍스트 로드 중: '/content/drive/MyDrive/PROJECT/cn_api_project/data/보험약관/summary/삼성화재_반려묘보험_의기냥냥_summary.txt' ---
# 약관 원문 전체 텍스트 로드 완료.
# 로드된 텍스트 길이: 173890 문자.
# 총 100개의 청크로 분할됨. (chunk_size=2000, overlap=200)
#
# --- [1/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [2/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [3/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [4/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [5/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [6/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [7/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [8/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [9/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [10/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [11/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [12/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [13/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [14/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [15/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [16/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
# 벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.
#
# --- GPT 심층 이해 분석 시작 (CoT 유도) ---
# !!! 오류: GPT 심층 이해 분석 중 오류 발생: 'TextGenerationPipeline' object has no attribute 'invoke' !!!
# GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.
#
# --- [17/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-fed9dc37f5c0> in <cell line: 0>()
#      36
#      37 # 3. GPT + RAG로 하나씩 분석
# ---> 38 final_summary = analyze_chunks_individually(text_chunks, rag_vectorstore, llm)
#      39
#      40
#
# <ipython-input-30-6829ca56feb3> in analyze_chunks_individually(text_chunks, rag_vectorstore, llm)
#       4     for i, chunk in enumerate(text_chunks):
#       5         print(f"\n--- [{i+1}/{len(text_chunks)}] 번째 청크 분석 시작 ---")
# ----> 6         result = analyze_clause_deeply(chunk, rag_vectorstore, llm)
#       7         all_results.append(f"🔹 [청크 {i+1} 분석 결과]\n{result}\n")
#       8
#
# <ipython-input-39-f5de619805cc> in analyze_clause_deeply(clause_text, rag_vectorstore, llm, num_rag_results, model)
#      10         try:
#      11             retriever = rag_vectorstore.as_retriever(search_kwargs={"k": num_rag_results})
# ---> 12             retrieved_docs = retriever.invoke(clause_text)
#      13             rag_context_text = "\n----\n".join([
#      14                 f"출처: {doc.metadata.get('source', '알 수 없음')}, 페이지: {doc.metadata.get('page', '알 수 없음')}\n{doc.page_content}"
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/retrievers.py in invoke(self, input, config, **kwargs)
#     257             _kwargs = kwargs if self._expects_other_args else {}
#     258             if self._new_arg_supported:
# --> 259                 result = self._get_relevant_documents(
#     260                     input, run_manager=run_manager, **_kwargs
#     261                 )
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/vectorstores/base.py in _get_relevant_documents(self, query, run_manager, **kwargs)
#    1077         _kwargs = self.search_kwargs | kwargs
#    1078         if self.search_type == "similarity":
# -> 1079             docs = self.vectorstore.similarity_search(query, **_kwargs)
#    1080         elif self.search_type == "similarity_score_threshold":
#    1081             docs_and_similarities = (
#
# /usr/local/lib/python3.11/dist-packages/langchain_chroma/vectorstores.py in similarity_search(self, query, k, filter, **kwargs)
#     601             List of documents most similar to the query text.
#     602         """
# --> 603         docs_and_scores = self.similarity_search_with_score(
#     604             query, k, filter=filter, **kwargs
#     605         )
#
# /usr/local/lib/python3.11/dist-packages/langchain_chroma/vectorstores.py in similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     698             )
#     699         else:
# --> 700             query_embedding = self._embedding_function.embed_query(query)
#     701             results = self.__query_collection(
#     702                 query_embeddings=[query_embedding],
#
# /usr/local/lib/python3.11/dist-packages/langchain_openai/embeddings/base.py in embed_query(self, text, **kwargs)
#     636             Embedding for the text.
#     637         """
# --> 638         return self.embed_documents([text], **kwargs)[0]
#     639
#     640     async def aembed_query(self, text: str, **kwargs: Any) -> list[float]:
#
# /usr/local/lib/python3.11/dist-packages/langchain_openai/embeddings/base.py in embed_documents(self, texts, chunk_size, **kwargs)
#     588         #       than the maximum context and use length-safe embedding function.
#     589         engine = cast(str, self.deployment)
# --> 590         return self._get_len_safe_embeddings(
#     591             texts, engine=engine, chunk_size=chunk_size, **kwargs
#     592         )
#
# /usr/local/lib/python3.11/dist-packages/langchain_openai/embeddings/base.py in _get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     476         batched_embeddings: list[list[float]] = []
#     477         for i in _iter:
# --> 478             response = self.client.create(
#     479                 input=tokens[i : i + _chunk_size], **client_kwargs
#     480             )
#
# /usr/local/lib/python3.11/dist-packages/openai/resources/embeddings.py in create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     127             return obj
#     128
# --> 129         return self._post(
#     130             "/embeddings",
#     131             body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1237             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238         )
# -> 1239         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1240
#    1241     def patch(
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#     967             response = None
#     968             try:
# --> 969                 response = self._client.send(
#     970                     request,
#     971                     stream=stream or self._should_stream_response_body(request=request),
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1012
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#    1016         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.11/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     248         )
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#     252         assert isinstance(resp.stream, typing.Iterable)
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     254
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#     258         # Return the response. Note that in this case we still have to manage
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     234                 try:
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#     238                     )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     101             raise exc
#     102
# --> 103         return self._connection.handle_request(request)
#     104
#     105     def _connect(self, request: Request) -> NetworkStream:
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     134                 with Trace("response_closed", logger, request) as trace:
#     135                     self._response_closed()
# --> 136             raise exc
#     137
#     138     # Sending the request...
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     104                     headers,
#     105                     trailing_data,
# --> 106                 ) = self._receive_response_headers(**kwargs)
#     107                 trace.return_value = (
#     108                     http_version,
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     175
#     176         while True:
# --> 177             event = self._receive_event(timeout=timeout)
#     178             if isinstance(event, h11.Response):
#     179                 break
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     215
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#     219                 )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#     126         with map_exceptions(exc_map):
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#     130     def write(self, buffer: bytes, timeout: float | None = None) -> None:
#
# /usr/lib/python3.11/ssl.py in recv(self, buflen, flags)
#    1293                     "non-zero flags not allowed in calls to recv() on %s" %
#    1294                     self.__class__)
# -> 1295             return self.read(buflen)
#    1296         else:
#    1297             return super().recv(buflen, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1166                 return self._sslobj.read(len, buffer)
#    1167             else:
# -> 1168                 return self._sslobj.read(len)
#    1169         except SSLError as x:
#    1170             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
def load_summary_text(summary_file_path):
    summary_clause_text = ""
    print(f"\n--- 분석 대상 약관 원문 전체 텍스트 로드 중: '{summary_file_path}' ---")
    try:
        if os.path.exists(summary_file_path):
            with open(summary_file_path, 'r', encoding='utf-8') as f:
                summary_clause_text = f.read()
            print("약관 원문 전체 텍스트 로드 완료.")
            print(f"로드된 텍스트 길이: {len(summary_clause_text)} 문자.")
        else:
            print(f"!!! 오류: 약관 원문 전체 텍스트 파일을 찾을 수 없습니다 - '{summary_file_path}' !!!")
            print("경로와 파일 이름을 확인하세요.")
    except Exception as e:
        print(f"!!! 오류: 약관 원문 전체 텍스트 로드 중 예외 발생: {e} !!!")
    return summary_clause_text

# %%
def analyze_clause_deeply(clause_text, rag_vectorstore, llm, num_rag_results=5, model="gpt-4o-2024-05-13"):

    if llm is None:
        print("!!! 오류: GPT 모델(llm)이 로드되지 않아 분석을 진행할 수 없습니다. API 키 설정 확인 필요. !!!")
        return "분석 실패: GPT 모델 오류"
        # RAG 검색은 rag_vectorstore가 None이 아니면 시도합니다.
        rag_context_text = "참고 자료 없음 (벡터 스토어 로드 실패)."
    if rag_vectorstore is not None:
        print("\n--- RAG 검색 시작 ---")
        try:
            retriever = rag_vectorstore.as_retriever(search_kwargs={"k": num_rag_results})
            retrieved_docs = retriever.invoke(clause_text)
            rag_context_text = "\n----\n".join([
                f"출처: {doc.metadata.get('source', '알 수 없음')}, 페이지: {doc.metadata.get('page', '알 수 없음')}\n{doc.page_content}"
                for doc in retrieved_docs
            ])
            print(f"RAG 검색 완료. 총 {len(retrieved_docs)}개의 참고 자료 확보.")
        except Exception as e:
            print(f"!!! 오류: RAG 검색 중 오류 발생: {e} !!!")
            print("벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.")
            rag_context_text = "오류 발생: 참고 자료 검색 실패."

    # GPT 프롬프트 메시지 구성 (약관 문구 + RAG Context 포함)
    message = deep_understanding_template.format(
        clause_text=clause_text,
        rag_context=rag_context_text if rag_context_text else "참고 자료 없음."
    )

    # GPT 모델 호출 (심층 이해 분석 및 CoT 추론)
    print("\n--- GPT 심층 이해 분석 시작 (CoT 유도) ---")
    try:
        messages = [{"role": "user", "content": message}]
        response = llm.invoke(messages)
        response_text = response.content

        print("\n--- GPT 심층 이해 분석 완료 ---")
        return response_text

    except Exception as e:
        print(f"!!! 오류: GPT 심층 이해 분석 중 오류 발생: {e} !!!")
        print("GPT API 호출 중 문제 발생. API 키, 모델 이름, 토큰 제한 등을 확인하세요.")
        return f"분석 실패: GPT 오류 - {e}"

# %%
from transformers import pipeline

# 예시로 HuggingFace의 GPT2 또는 Mistral 모델을 사용할 수 있습니다.
# 사전 로딩된 pipeline (또는 사용자가 만든 HF pipeline)을 llm으로 받음
# 예: llm = pipeline("text-generation", model="mistralai/Mistral-7B-Instruct-v0.1", device=0)

def analyze_clause_deeply(clause_text, rag_vectorstore, llm, num_rag_results=5):
    rag_context_text = "참고 자료 없음."

    # RAG 검색 수행
    if rag_vectorstore is not None:
        print("\n--- RAG 검색 시작 ---")
        try:
            retriever = rag_vectorstore.as_retriever(search_kwargs={"k": num_rag_results})
            retrieved_docs = retriever.invoke(clause_text)
            rag_context_text = "\n----\n".join([
                f"출처: {doc.metadata.get('source', '알 수 없음')}, 페이지: {doc.metadata.get('page', '알 수 없음')}\n{doc.page_content}"
                for doc in retrieved_docs
            ])
            print(f"RAG 검색 완료. 총 {len(retrieved_docs)}개의 참고 자료 확보.")
        except Exception as e:
            print(f"!!! 오류: RAG 검색 중 오류 발생: {e} !!!")
            rag_context_text = "오류 발생: 참고 자료 검색 실패."

    # 프롬프트 구성
    prompt = deep_understanding_template.format(
        clause_text=clause_text,
        rag_context=rag_context_text
    )

    print("\n--- GPT(HF 모델) 심층 이해 분석 시작 ---")
    try:
        if hasattr(llm, "invoke"):  # OpenAI 방식
            messages = [{"role": "user", "content": prompt}]
            response = llm.invoke(messages)
            response_text = response.content

        else:  # HuggingFace pipeline 방식
            # huggingface text-generation pipeline 사용
            result = llm(prompt, max_new_tokens=1024, do_sample=True, temperature=0.7)
            response_text = result[0]['generated_text'] if isinstance(result, list) else str(result)

        print("--- GPT 심층 이해 분석 완료 ---")
        return response_text

    except Exception as e:
        print(f"!!! 오류: GPT(HF) 분석 중 오류 발생: {e} !!!")
        return f"분석 실패: 모델 오류 - {e}"

# %%
import os
os.environ["HUGGINGFACE_API_TOKEN"] = "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"

# %%
# 1. 텍스트 로딩
summary_clause_text = load_summary_text(summary_file_path)

# 2. 청크로 분할
text_chunks = split_text_into_chunks(summary_clause_text, chunk_size=2000)

# 3. GPT + RAG로 하나씩 분석
final_summary = analyze_chunks_individually(text_chunks, rag_vectorstore, llm)


# 4. 결과 출력 또는 저장
print("\n===== 전체 분석 결과 요약 =====\n")
print(final_summary[:1000])
# Out:
# --- 분석 대상 약관 원문 전체 텍스트 로드 중: '/content/drive/MyDrive/PROJECT/cn_api_project/data/보험약관/summary/삼성화재_반려묘보험_애니펫_summary.txt' ---
# 약관 원문 전체 텍스트 로드 완료.
# 로드된 텍스트 길이: 71103 문자.
# 총 40개의 청크로 분할됨. (chunk_size=2000, overlap=200)
#
# --- [1/40] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
#
# --- GPT(HF 모델) 심층 이해 분석 시작 ---
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:463: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-33ab485962e8> in <cell line: 0>()
#       6
#       7 # 3. GPT + RAG로 하나씩 분석
# ----> 8 final_summary = analyze_chunks_individually(text_chunks, rag_vectorstore, llm)
#       9
#      10
#
# <ipython-input-30-6829ca56feb3> in analyze_chunks_individually(text_chunks, rag_vectorstore, llm)
#       4     for i, chunk in enumerate(text_chunks):
#       5         print(f"\n--- [{i+1}/{len(text_chunks)}] 번째 청크 분석 시작 ---")
# ----> 6         result = analyze_clause_deeply(chunk, rag_vectorstore, llm)
#       7         all_results.append(f"🔹 [청크 {i+1} 분석 결과]\n{result}\n")
#       8
#
# <ipython-input-33-135d3b940472> in analyze_clause_deeply(clause_text, rag_vectorstore, llm, num_rag_results)
#      38         else:  # HuggingFace pipeline 방식
#      39             # huggingface text-generation pipeline 사용
# ---> 40             result = llm(prompt, max_new_tokens=1024, do_sample=True, temperature=0.7)
#      41             response_text = result[0]['generated_text'] if isinstance(result, list) else str(result)
#      42
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     300                     else:
#     301                         return super().__call__(list(chats), **kwargs)
# --> 302         return super().__call__(text_inputs, **kwargs)
#     303
#     304     def preprocess(
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1429             )
#    1430         else:
# -> 1431             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1432
#    1433     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1436     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1437         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1438         model_outputs = self.forward(model_inputs, **forward_params)
#    1439         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1440         return outputs
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1336                 with inference_context():
#    1337                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1338                     model_outputs = self._forward(model_inputs, **forward_params)
#    1339                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1340             else:
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     398             generate_kwargs["generation_config"] = self.generation_config
#     399
# --> 400         output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     401
#     402         if isinstance(output, ModelOutput):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2595
#    2596             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2597             result = self._sample(
#    2598                 input_ids,
#    2599                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3555
#    3556             if is_prefill:
# -> 3557                 outputs = self(**model_inputs, return_dict=True)
#    3558                 is_prefill = False
#    3559             else:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     967
#     968         try:
# --> 969             output = func(self, *args, **kwargs)
#     970             if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     971                 output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, cache_position, logits_to_keep, **kwargs)
#     704         # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#     705         slice_indices = slice(-logits_to_keep, None) if isinstance(logits_to_keep, int) else logits_to_keep
# --> 706         logits = self.lm_head(hidden_states[:, slice_indices, :])
#     707
#     708         loss = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
summary_file_path = '/content/drive/MyDrive/PROJECT/cn_api_project/data/보험약관/summary/삼성화재_반려묘보험_의기냥냥_summary.txt'

# %%
 # 1. 텍스트 로딩
summary_clause_text = load_summary_text(summary_file_path)

# 2. 청크로 분할
text_chunks = split_text_into_chunks(summary_clause_text, chunk_size=2000)

# 3. GPT + RAG로 하나씩 분석
final_summary = analyze_chunks_individually(text_chunks, rag_vectorstore, llm)


# 4. 결과 출력 또는 저장
print("\n===== 전체 분석 결과 요약 =====\n")
print(final_summary[:1000])
# Out:
# --- 분석 대상 약관 원문 전체 텍스트 로드 중: '/content/drive/MyDrive/PROJECT/cn_api_project/data/보험약관/summary/삼성화재_반려묘보험_의기냥냥_summary.txt' ---
# 약관 원문 전체 텍스트 로드 완료.
# 로드된 텍스트 길이: 173890 문자.
# 총 100개의 청크로 분할됨. (chunk_size=2000, overlap=200)
#
# --- [1/100] 번째 청크 분석 시작 ---
#
# --- RAG 검색 시작 ---
# !!! 오류: RAG 검색 중 오류 발생: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}} !!!
#
# --- GPT(HF 모델) 심층 이해 분석 시작 ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-33ab485962e8> in <cell line: 0>()
#       6
#       7 # 3. GPT + RAG로 하나씩 분석
# ----> 8 final_summary = analyze_chunks_individually(text_chunks, rag_vectorstore, llm)
#       9
#      10
#
# <ipython-input-30-6829ca56feb3> in analyze_chunks_individually(text_chunks, rag_vectorstore, llm)
#       4     for i, chunk in enumerate(text_chunks):
#       5         print(f"\n--- [{i+1}/{len(text_chunks)}] 번째 청크 분석 시작 ---")
# ----> 6         result = analyze_clause_deeply(chunk, rag_vectorstore, llm)
#       7         all_results.append(f"🔹 [청크 {i+1} 분석 결과]\n{result}\n")
#       8
#
# <ipython-input-33-135d3b940472> in analyze_clause_deeply(clause_text, rag_vectorstore, llm, num_rag_results)
#      38         else:  # HuggingFace pipeline 방식
#      39             # huggingface text-generation pipeline 사용
# ---> 40             result = llm(prompt, max_new_tokens=1024, do_sample=True, temperature=0.7)
#      41             response_text = result[0]['generated_text'] if isinstance(result, list) else str(result)
#      42
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     300                     else:
#     301                         return super().__call__(list(chats), **kwargs)
# --> 302         return super().__call__(text_inputs, **kwargs)
#     303
#     304     def preprocess(
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1429             )
#    1430         else:
# -> 1431             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1432
#    1433     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1436     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1437         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1438         model_outputs = self.forward(model_inputs, **forward_params)
#    1439         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1440         return outputs
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1336                 with inference_context():
#    1337                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1338                     model_outputs = self._forward(model_inputs, **forward_params)
#    1339                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1340             else:
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     398             generate_kwargs["generation_config"] = self.generation_config
#     399
# --> 400         output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     401
#     402         if isinstance(output, ModelOutput):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2595
#    2596             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2597             result = self._sample(
#    2598                 input_ids,
#    2599                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3555
#    3556             if is_prefill:
# -> 3557                 outputs = self(**model_inputs, return_dict=True)
#    3558                 is_prefill = False
#    3559             else:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     967
#     968         try:
# --> 969             output = func(self, *args, **kwargs)
#     970             if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     971                 output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, cache_position, logits_to_keep, **kwargs)
#     688
#     689         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 690         outputs: BaseModelOutputWithPast = self.model(
#     691             input_ids=input_ids,
#     692             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     967
#     968         try:
# --> 969             output = func(self, *args, **kwargs)
#     970             if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     971                 output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, cache_position, **flash_attn_kwargs)
#     421                 all_hidden_states += (hidden_states,)
#     422
# --> 423             layer_outputs = decoder_layer(
#     424                 hidden_states,
#     425                 attention_mask=causal_mask,
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      46         if self.gradient_checkpointing and self.training:
#      47             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 48         return super().__call__(*args, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     257         # Fully Connected
#     258         residual = hidden_states
# --> 259         hidden_states = self.post_attention_layernorm(hidden_states)
#     260         hidden_states = self.mlp(hidden_states)
#     261         hidden_states = residual + hidden_states
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, hidden_states)
#     210         hidden_states = hidden_states.to(torch.float32)
#     211         variance = hidden_states.pow(2).mean(-1, keepdim=True)
# --> 212         hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#     213         return self.weight * hidden_states.to(input_dtype)
#     214
#
# KeyboardInterrupt:

# %% [markdown]
# ---

# %% [markdown]
# ### 결과 저장

# %%
# !pip install FPDF
from fpdf import FPDF
# Out:
# Collecting FPDF
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: FPDF
#   Building wheel for FPDF (setup.py) ... done
#   Created wheel for FPDF: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=e45bdd8f1b1db078cc650a7b001bd808fc8d1891387d0ed75884e024cbb584e0
#   Stored in directory: /root/.cache/pip/wheels/65/4f/66/bbda9866da446a72e206d6484cd97381cbc7859a7068541c36
# Successfully built FPDF
# Installing collected packages: FPDF
# Successfully installed FPDF-1.7.2

# %%
# 저장할 Google Drive 경로 설정 (마운트 후 사용)
BASE_GDRIVE_FOLDER = "/content/drive/MyDrive/PROJECT/cn_api_project"
OUTPUT_FOLDER_NAME = "insurance_outputs"

# %% [markdown]
# > 폴더 생성 유틸 함수

# %%
# 폴더 생성 유틸 함수
def ensure_output_folder_exists():
    folder_path = os.path.join(BASE_GDRIVE_FOLDER, OUTPUT_FOLDER_NAME)
    os.makedirs(folder_path, exist_ok=True)
    return folder_path

# %% [markdown]
# > txt 저장 함수

# %%
# ❷ 분석 대상이었던 원본 파일 경로
# original_path = "/content/drive/MyDrive/PROJECT/cn_api_project/data/보험약관/summary/삼성화재_반려묘보험_애니펫_summary.txt"

# %%
def save_summary_to_txt(summary_text, original_path, suffix="_outputs.txt"):
    folder_path = ensure_output_folder_exists()

    # 원래 파일명에서 확장자 제거하고 suffix 추가
    original_filename = os.path.basename(original_path)  # 예: "summary_cat_insurance_A.txt"
    filename_without_ext = os.path.splitext(original_filename)[0]  # 예: "summary_cat_insurance_A"
    new_filename = filename_without_ext + suffix  # 예: "summary_cat_insurance_A_outputs.txt"

    file_path = os.path.join(folder_path, new_filename)

    with open(file_path, "w", encoding="utf-8") as f:
        f.write(summary_text)

    print(f"✅ 텍스트 저장 완료: {file_path}")
    return file_path

# %% [markdown]
# > 실행

# %%
# 텍스트 저장
save_summary_to_txt(final_summary, original_path = summary_file_path)
# Out:
# ✅ 텍스트 저장 완료: /content/drive/MyDrive/PROJECT/cn_api_project/insurance_outputs/hanhwa_pet_terms_summary_outputs.txt
# '/content/drive/MyDrive/PROJECT/cn_api_project/insurance_outputs/hanhwa_pet_terms_summary_outputs.txt'

# %% [markdown]
# ## Step 2: 잠재적 '문제점 발상' 및 근거 제시 (ToT 발상 + CoT 근거, RAG 필수 활용)
#
# ### 목표: 약관의 잠재적 문제점을 다양하게 발상하고, 그 근거를 제시하는 것. 이때 RAG를 적극적으로 활용해서 더 현실적이고 근거가 풍부한 문제점을 발상
# ### 수정 내용:
# * 잠재적 문제점 발상을 시킬 때, **GPT 프롬프트에 분석 대상 약관 원문 텍스트와 함께 Step 1에서 검색된 외부 참고 자료(벡터 스토어 검색 결과)**를 반드시 포함
#
# * 프롬프트 지침에 "제공된 약관 내용과 **추가 참고 자료**를 꼼꼼히 비교하며 문제점을 발상하라"고 명시
#
#
# * 특히 문제점의 '근거 및 추론 과정' (CoT) 부분을 설명할 때, 약관 원문의 어떤 문구와 더불어 추가 참고 자료의 어떤 내용을 참고해서 그 문제점을 발상하게 되었는지 구체적으로 언급하도록 유도. (예: "약관 제X조 Y항 내용과 금감원 분쟁 사례집 Z 페이지의 유사 사례를 보니 이런 문제가 발생할 수 있습니다.")
#
#
# * 이전 약관 전체 요약 내용도 여전히 컨텍스트로 함께 제공해서 전체 맥락 따름.
#
#
# * ToT 발상 단계이므로 temperature는 좀 높게 유지, Self-consistency로 여러 후보를 생성하고 안정적인 목록을 선택하는 것은 동일 적용.
# -----

# %% [markdown]
# ### 함수 정의

# %% [markdown]
# #### problem_sampling_template_rag
# > 프롬프트 템플릿 생성

# %%
# --- 2단계 - 잠재적 문제점 발상 프롬프트 템플릿 (보충된 버전) ---
problem_sampling_template_rag = """
## 역할: 소비자 권익 보호를 위해 보험 약관의 숨겨진 위험을 분석·탐지하는 전문 분석가

## 임무:
아래의 세 가지 자료:
- **[분석 대상 약관 원문 텍스트]**
- **[이전 약관 전체 요약] (전체 맥락 이해용)**
- **[추가 참고 자료] (법령, 판례, 분쟁 사례, 유사 약관 등)**

를 **통합적으로 비교·검토**하여, 다음을 수행하세요:

> 소비자가 **오해하거나 손해를 볼 수 있는 모든 잠재적 문제점**을 철저하고 창의적으로 발굴합니다. 마치 **약관 속 숨겨진 함정을 파헤치는 전문가**처럼, 약관의 허점·위험·모순·비현실성을 **RAG 기반으로 탐지**해 주세요.

---

### 🔍 분석 방법 지침:

1. **비판적 분석 및 비교 시각 유지:**
   - 원문 약관의 문장/용어/구조를 **정밀 분석**합니다.
   - 이전 약관 요약을 참고하여 **문맥적 흐름과 변화**를 파악합니다.
   - 특히, **[추가 참고 자료]와의 비교**를 통해 문제점을 도출하세요.
     > 예: 법령/판례와의 불일치, 금감원 분쟁 사례의 유사 피해, 유사 약관과의 격차 등

2. **다양한 관점에서 창의적 문제점 발상 (ToT):**
   - 다음과 같은 관점으로 **잠재적 리스크**를 다양한 시나리오로 탐색합니다 (**최소 7건 이상**):
     * 약관 문구의 모호성/다의성
     * 보장 및 면책 범위의 불명확성
     * 고지 의무/통지 의무 관련 위험
     * 보험금 청구/지급 절차의 불합리
     * 조항 간 상충 가능성
     * 법률/판례/유사 약관과의 불일치
     * 의료 현실 또는 소비자 행동과의 괴리
     * 소비자에게 중요한 정보의 미노출
     * 기타 예상 외 시나리오

3. **문제점의 발생 논리 및 근거 제시 (CoT):**
   각 문제점은 반드시 다음의 구조에 따라 **구체적이고 신뢰성 있는 추론**을 포함해야 합니다:

   | 항목 | 설명 |
   |------|------|
   | (A) 분석 대상 약관 문구 | 어떤 문구를 문제의 핵심으로 보았는지 직접 인용 |
   | (B) 비교한 참고 자료 | 어떤 법령, 분쟁 사례, 유사 약관과 비교했는지 |
   | (C) 문제 도출 논리 | 이 비교를 통해 어떤 논리적 이유로 문제가 발생한다고 보았는지 |

   예시:
   - 약관 제6조 3항의 "정신질환으로 인한 입원은 보장하지 않음" →
   - [참고자료] 금감원 분쟁사례집 2023, p.47: '우울증 입원 보장 관련 분쟁 사례' →
   - 의료기관 입원이 지속 증가하는 현실과 괴리가 있으며, 정신질환자의 실질 보장이 불가함

4. **추가 지침:**
   - 각 문제점은 **[추가 참고 자료]에서 최소 1개 이상 인용하지 않으면 제외**합니다.
   - `"문제점_유형"`은 아래 중 복수 선택 가능:
     * 모호한 표현
     * 보상 제외 조건의 불명확성
     * 고지 의무/통지 의무
     * 지급/청구 절차
     * 문서 내 상충 조항
     * 법령/판례와의 불일치
     * 현실과의 괴리
     * 소비자에게 불리한 정보 미노출
     * 기타

5. **[선택적] 신뢰도 등급 (신뢰/주의/불확실):**
   - 참고자료와의 논리적 정합성, 반복적 사례 존재 여부 등을 바탕으로, 문제점의 근거 신뢰도 등급을 평가할 수 있습니다.

---

## 출력 포맷 (JSON):

```json
{{
  "잠재적_문제점_후보": [
    {{
      "id": 1,
      "간단_표시용_요약": "정신질환 입원 보장 제외로 인한 사각지대",
      "문제점_요약": "정신질환 입원 불인정 조항",
      "발생_가능_시나리오": "우울증으로 입원한 가입자가 보험금을 청구했으나, 해당 조항에 따라 지급 거부됨",
      "근거_및_추론과정": "약관 제6조 3항에서 정신질환 입원을 보장하지 않음. 금감원 분쟁사례집 2023 p.47에서 유사한 사례 발생. 현실에서는 정신질환 입원이 반복되는 구조이나 이 조항은 전면 배제함.",
      "관련_약관_원문_표현": "정신질환으로 인한 입원은 보험금 지급 대상에서 제외",
      "문제점_유형": ["보상 제외 조건의 불명확성", "현실과의 괴리"],
      "예상_소비자_영향": "보험금 전액 미지급",
      "참고_자료_출처": ["금감원 분쟁사례집 2023 p.47", "보험업감독규정 제9조"],
      "근거_신뢰도": "신뢰"
    }}
    // ... more 문제점 ...
  ]
}}
"""

# %% [markdown]
# #### request_gpt 헬퍼 함수

# %%
def request_gpt(message, model="gpt-4o-2024-05-13", temperature=0.7, type="json_object"):
# 이 함수는 openai.OpenAI() 클라이언트 객체를 사용합니다.
# client 객체가 위에 정의되어 있다고 가정합니다.
    if client is None:
        print("API 클라이언트가 초기화되지 않았습니다.")
        return {} if type == "json_object" else "API 클라이언트 오류"

    messages = [{"role": "user", "content": message}]
    try:
        response = client.chat.completions.create(
                model=model,
                messages=messages,
                temperature=temperature,
                response_format={"type" : type}
            ).model_dump()
        content = response['choices'][0]['message']['content']
        if type == "json_object":
            content = content.strip()
            # 가끔 ```json ... ``` 형태로 오는 응답 처리
            if content.startswith("```json"): content = content[7:]
            if content.endswith("```"): content = content[:-3]
            content = content.strip()
            return json.loads(content)
        else: return content
    except Exception as e:
        print(f"API 호출 중 오류 발생: {e}")
        return {} if type == "json_object" else f"API Error: {e}"

# %% [markdown]
# #### identify_potential_problems_with_rag 함수 정의
#
#
# > (analysis_target_text, previous_full_summary, rag_vectorstore, iterations=7, model="gpt-4o-2024-05-13", temperature=0.7)

# %%
def identify_potential_problems_with_rag(analysis_target_text, previous_full_summary, rag_vectorstore, iterations=7, model="gpt-4o-2024-05-13", temperature=0.7):
    if client is None:
        print("\n!!! API 클라이언트가 초기화되지 않아 문제점 발상을 실행할 수 없습니다. !!!")
        return []
    # RAG 검색은 rag_vectorstore가 None이 아니면 시도합니다.
    rag_context_text = "참고 자료 검색 실패 또는 없음." # 초기값 설정
    if rag_vectorstore is not None:
        print("\n--- RAG 검색 시작 ---")
        try:
            retriever = rag_vectorstore.as_retriever(search_kwargs={"k": 5}) # 관련 문서 청크 5개 검색 (조절 가능)

            # RAG 검색 실행: 분석 대상 텍스트를 쿼리로 사용
            # 분석 대상 텍스트 전체가 너무 길 수 있으므로 일부만 쿼리로 사용 (예: 앞 500자)
            query_text_for_rag = analysis_target_text[:500] # 쿼리 길이를 제한하여 검색 (조절 필요)
            if not query_text_for_rag.strip():
                print("경고: 분석 대상 텍스트가 비어있거나 너무 짧아 RAG 검색 쿼리 생성 불가.")
                rag_context_text = "분석 대상 텍스트 부족: 참고 자료 검색 불가."
            else:
                retrieved_docs = retriever.invoke(query_text_for_rag)
                rag_context_text = "\n----\n".join([
                    f"출처: {doc.metadata.get('source', '알 수 없음')}, 페이지: {doc.metadata.get('page', '알 수 없음')}\n{doc.page_content}"
                    for doc in retrieved_docs
                ])
                print(f"RAG 검색 완료. 총 {len(retrieved_docs)}개의 참고 자료 확보.")
                # print(f"참고 자료 일부:\n{rag_context_text[:500]}...") # 디버깅용

        except Exception as e:
            print(f"!!! 오류: RAG 검색 중 오류 발생: {e} !!!")
            print("벡터 스토어 로드 상태, 임베딩 모델, API 키 등을 확인하세요.")
            rag_context_text = "오류 발생: 참고 자료 검색 실패."

    # Self-consistency를 위한 발상 반복
    problem_list_counts = defaultdict(int)
    problem_list_details = {}

    print (f"\n===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 ({iterations}회 반복) =====")

    sampling_temperature = temperature # 발상 온도 사용 (보통 0.7 ~ 1.0)

    for i in range(iterations):
        print(f"\n----- [{i+1}/{iterations} 번째 문제점 발상 시도 중] -----")

        # 프롬프트 메시지 구성 (보충된 템플릿 사용)
        message = problem_sampling_template_rag.format(
            previous_full_summary=previous_full_summary if previous_full_summary else "없음",
            analysis_target_text=analysis_target_text, # 분석 대상 텍스트 전체 전달
            rag_context=rag_context_text if rag_context_text else "참고 자료 없음." # RAG 검색 결과 전달!
        )

        try:
            # request_gpt 함수 사용 (client 객체 사용)
            response_json = request_gpt(
                message,
                model=model,
                temperature=sampling_temperature,
                type="json_object" # JSON 형태로 응답 요청
            )

            # 응답 형식이 기대와 다를 경우 처리
            if not isinstance(response_json, dict) or "잠재적_문제점_후보" not in response_json:
                print("문제점 발상 응답 형식이 올바르지 않습니다. 결과 스킵.")
                print(f"Raw Response Sample: {str(response_json)[:200]}...")
                continue # 이번 결과는 무시

            problem_candidates = response_json.get("잠재적_문제점_후보", [])

            # 문제점 후보 목록을 문자열로 변환하여 일관성 체크 기준 마련 (JSON 정규화)
            problem_list_string_key = json.dumps(problem_candidates, sort_keys=True, ensure_ascii=False)

            # 결과가 비어있거나 너무 적으면 스킵
            if not problem_candidates or len(problem_candidates) < 3: # 최소 후보 개수 기준 (조절 필요)
                print(f"발상된 문제점 후보 개수가 부족합니다 ({len(problem_candidates)}개). 결과 스킵.")
                continue

            # print(f"발상된 문제점 후보 목록 (총 {len(problem_candidates)}개) 생성 완료.") # 디버깅용

            problem_list_counts[problem_list_string_key] += 1
            if problem_list_string_key not in problem_list_details:
                problem_list_details[problem_list_string_key] = problem_candidates

        except Exception as e:
            print(f"API 호출 중 오류 발생 또는 JSON 처리 오류: {e}")
            error_key = f"[API 오류: {e}]"
            problem_list_counts[error_key] += 1


    # Self-consistency 결과 요약 및 최빈값 선택
    print(f"\n===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====")
    if not problem_list_counts:
        print("문제점 발상 결과가 없습니다.")
        return []

    sorted_results = sorted(problem_list_counts.items(), key=lambda x: x[1], reverse=True)
    for key_string, count in sorted_results:
        display_key = key_string[:100].replace('\n', ' ') + '...' if len(key_string) > 100 else key_string
        print(f"'{display_key}': {count}회")

    most_frequent_list_key = sorted_results[0][0]

    print(f"\n===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====")
    final_problem_candidates_list = problem_list_details.get(most_frequent_list_key, [])
    print(f"총 {len(final_problem_candidates_list)}개의 문제점 후보 선정 (Self-consistency 기반):")
    for p in final_problem_candidates_list:
        # f-string 오류 방지를 위해 replace('\n', ' ') 결과를 변수에 먼저 저장 후 사용
        근거_CoT_display = p.get('근거_및_추론과정', 'N/A')[:150].replace('\n', ' ')
        print(f"- 요약: {p.get('문제점_요약', 'N/A')}")
        print(f"  근거 (CoT): {근거_CoT_display}...") # 수정된 부분
        print(f"  관련 약관/자료: {p.get('관련_약관_원문_표현', 'N/A')} | 출처: {p.get('참고_자료_출처', 'N/A')}")
        print("-" * 20)

    return final_problem_candidates_list

# %% [markdown]
# #### run_problem_identification_step 함수 정의
#
#
# > 2단계 잠재적 문제점 발상 및 근거 제시 과정</br>
# use_rag=True 이고 rag_vectorstore가 제공되면 RAG 발상을 사용

# %%
def run_problem_identification_step(analysis_text, previous_summary, use_rag=False, rag_vectorstore=None, iterations=7, model="gpt-4o-2024-05-13", temperature=0.7):
    if use_rag and rag_vectorstore is not None:
        print("\n--- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---")
        problem_candidates = identify_potential_problems_with_rag(
        analysis_target_text=analysis_text,
        previous_full_summary=previous_summary,
        rag_vectorstore=rag_vectorstore,
        iterations=iterations,
        model=model,
        temperature=temperature # 발상 온도
        )
    else:
        print("\n--- [2단계] 일반 잠재적 문제점 발상 시작 (RAG 비활성) ---")
        problem_candidates = identify_potential_problems_with_rag(
        analysis_target_text=analysis_text,
        previous_full_summary=previous_summary,
        rag_vectorstore=None, # RAG 비활성 시 None 전달
        iterations=iterations,
        model=model,
        temperature=temperature
        )
    print(f"\n--- [2단계] 잠재적 문제점 발상 완료. 총 {len(problem_candidates)}개의 후보 선정. ---")
    return problem_candidates

# %% [markdown]
# ### 실행 예시를 위한 입력 데이터 준비 (전체 약관 원문 + 전체 요약)

# %% [markdown]
# #### 실행 예시를 위한 입력 데이터 준비 (약관 원문 TXT 파일 로드)

# %%
full_policy_text_file_path = '/content/drive/MyDrive/PROJECT/cn_api_project/txt/full/무배당 삼성화재 다이렉트보험약관.txt'

# %%
analysis_target_text_full = "" # 변수 초기화
print(f"\n--- 분석 대상 약관 원문 전체 텍스트 로드 중: '{full_policy_text_file_path}' ---")
try: # 파일 존재 확인
    if os.path.exists(full_policy_text_file_path):
    # 파일 읽기 모드('r', read)로 열고 전체 내용 읽기
        with open(full_policy_text_file_path, 'r', encoding='utf-8') as f:
            analysis_target_text_full = f.read()
        print("약관 원문 전체 텍스트 로드 완료.")
        print(f"로드된 텍스트 길이: {len(analysis_target_text_full)} 문자.")
    else:
        print(f"!!! 오류: 약관 원문 전체 텍스트 파일을 찾을 수 없습니다 - '{full_policy_text_file_path}' !!!")
        print("Google Drive 마운트 상태와 경로를 확인해주세요.")
        analysis_target_text_full = "" # 파일 없으면 빈 문자열

except Exception as e:
    print(f"!!! 오류: 약관 원문 전체 텍스트 로드 중 오류 발생: {e} !!!")
    analysis_target_text_full = "" # 로드 실패 시 빈 문자열
# Out:
# --- 분석 대상 약관 원문 전체 텍스트 로드 중: '/content/drive/MyDrive/UNIV./25-1/컴퓨터네트워크/cn_api_project/txt/full/무배당 삼성화재 다이렉트보험약관.txt' ---
# 약관 원문 전체 텍스트 로드 완료.
# 로드된 텍스트 길이: 219962 문자.

# %% [markdown]
# #### 이전 약관 전체 요약 내용 (previous_full_summary)

# %%
previous_summary_file_path = '/content/drive/MyDrive/UNIV./25-1/컴퓨터네트워크/cn_api_project/txt/summary/full_summary.txt'

# %%
previous_full_summary_text = "" # 변수 초기화
print(f"\n--- 이전 약관 전체 요약 텍스트 로드 중: '{previous_summary_file_path}' ---")
try:
    # 파일 존재 확인
    if os.path.exists(previous_summary_file_path):
    # 파일 읽기 모드('r', read)로 열고 전체 내용 읽기
        with open(previous_summary_file_path, 'r', encoding='utf-8') as f:
            previous_full_summary_text = f.read()
            print("이전 약관 전체 요약 로드 완료.")
            print(f"로드된 텍스트 길이: {len(previous_full_summary_text)} 문자.")
    else:
        print(f"!!! 경고: 이전 약관 전체 요약 파일을 찾을 수 없습니다 - '{previous_summary_file_path}' !!!")
        print("이전 약관 요약 없이 문제점 발상이 진행됩니다.")
        previous_full_summary_text = "" # 파일 없으면 빈 문자열

except Exception as e:
    print(f"!!! 오류: 이전 약관 전체 요약 텍스트 로드 중 오류 발생: {e} !!!")
    previous_full_summary_text = "" # 로드 실패 시 빈 문자열
# Out:
# --- 이전 약관 전체 요약 텍스트 로드 중: '/content/drive/MyDrive/UNIV./25-1/컴퓨터네트워크/cn_api_project/txt/summary/full_summary.txt' ---
# 이전 약관 전체 요약 로드 완료.
# 로드된 텍스트 길이: 28235 문자.

# %% [markdown]
# ### 2단계 실행 예시 (문제점 발상)

# %% [markdown]
# > 벡터 스토어가 로드되었고 (rag_vectorstore is not None)
# GPT 모델이 로드되었다면 (llm is not None)
# 그리고 분석 대상 텍스트와 이전 요약 텍스트가 로드되었다면
# 2단계 분석을 실행

# %% [markdown]
# > 1. 약관 원문 전체 텍스트 분할: analysis_target_text_full 변수에 담긴 약관 원문 전체 텍스트를 적절한 크기(예: 3000~5000자)의 청크로 나눠. 이때 약관의 목차나 조항 기준으로 자르면 더 의미있는 단위가 될 수 있지만, 간단하게는 문자열 길이 기준으로 자를 수 있어.
# 2. 분할된 각 청크 순회: 나눠진 각 청크에 대해 반복문을 돌면서 문제점 발상 Self-consistency (run_problem_identification_step)를 실행해.
# 3. 프롬프트 내용: 각 반복 시 run_problem_identification_step 함수에 다음 내용을 전달해.
# analysis_text: 현재 반복에서 처리할 약관 원문 텍스트 청크 (전체 대신 부분!).
# previous_summary: 이전 약관 전체 요약 (이건 계속 전체를 넘겨줘도 괜찮을 거야).
# rag_vectorstore: 벡터 스토어 객체 (RAG 검색에 사용).
# 4. 결과 취합: 각 청크별로 발상된 문제점 후보 목록 결과들을 하나의 큰 리스트로 모아.

# %%
if rag_vectorstore is not None and llm is not None and analysis_target_text_full and previous_full_summary_text: # 입력 데이터도 확인
    print(f"\n--- 2단계 잠재적 문제점 발상 시작 (약관 원문 전체 대상, RAG 활용) ---")
# Out:
# --- 2단계 잠재적 문제점 발상 시작 (약관 원문 전체 대상, RAG 활용) ---

# %%
# --- 약관 원문 전체 텍스트를 청크로 분할 ---
chunk_size_analysis = 4000 # 분석 프롬프트에 넣을 텍스트 청크 크기 (토큰 고려 조절)
                               # gpt-4o 128k 토큰 감안, RAG 검색 결과 등 포함 시 안전하게 4000-8000자 추천
chunk_overlap_analysis = 500 # 청크 간 겹침 (컨텍스트 유지)

# Langchain RecursiveCharacterTextSplitter를 다시 사용하여 분할
# 임베딩 시 사용한 것과 동일하거나 다른 설정 사용 가능
analysis_text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size_analysis,
    chunk_overlap=chunk_overlap_analysis
        # chunk_size와 overlap 설정은 RAG 임베딩 시와 다를 수 있습니다.
        # 여기서는 분석 프롬프트에 들어갈 텍스트 양을 조절하는 목적입니다.
    )

# Document 객체로 만들어야 TextSplitter 사용 가능. 간단하게 전체 텍스트를 하나의 Document로 만듭니다.
# 메타데이터는 필요에 따라 추가 (예: source)
from langchain_core.documents import Document # 임포트 확인
doc_to_split = Document(page_content=analysis_target_text_full, metadata={"source": "원본 약관 전체"})

print(f"\n약관 원문 전체 텍스트 ({len(analysis_target_text_full)}자)를 {chunk_size_analysis}자씩 분할 중...")
analysis_chunks = analysis_text_splitter.split_documents([doc_to_split]) # split_documents는 Document 리스트를 받습니다.
print(f"약관 원문 전체 텍스트 분할 완료. 총 {len(analysis_chunks)}개의 분석 청크 생성.")
# Out:
# 약관 원문 전체 텍스트 (219962자)를 4000자씩 분할 중...
# 약관 원문 전체 텍스트 분할 완료. 총 63개의 분석 청크 생성.

# %%
all_problem_candidates_from_chunks = [] # 모든 청크에서 발상된 문제점 후보들을 모을 리스트

# --- 분할된 각 청크에 대해 문제점 발상 실행 ---
for i, chunk_doc in enumerate(analysis_chunks):
    current_analysis_chunk_text = chunk_doc.page_content # 현재 청크의 텍스트 내용
    print(f"\n\n===== [전체 약관 분석] 청크 {i+1}/{len(analysis_chunks)} 문제점 발상 시작 =====")

    # run_problem_identification_step 함수 호출하여 현재 청크에 대해 2단계 실행
    # analysis_text에 현재 청크 텍스트를 전달
    # previous_summary에 이전 약관 전체 요약 텍스트를 전달
    # use_rag=True로 설정하여 RAG 활성화 (각 청크 분석 시마다 관련 RAG 검색 수행)
    chunk_problem_candidates = run_problem_identification_step(
        analysis_text=current_analysis_chunk_text, # 분석 대상: 현재 약관 청크!
        previous_summary=previous_full_summary_text, # 이전 요약 내용 전체! (각 청크 분석 시마다 참고)
        use_rag=True, # RAG 활성화!
        rag_vectorstore=rag_vectorstore, # 로드된 벡터 스토어 전달
        iterations=1, # Self-consistency 반복 횟수 (각 청크별 반복) - 전체 실행 시간 고려 조절 필요!
        model="gpt-4o-2024-05-13", # GPT 모델
        temperature=1.0 # 발상 단계 온도
        )

    # 현재 청크에서 발상된 문제점 후보들을 전체 리스트에 추가
    all_problem_candidates_from_chunks.extend(chunk_problem_candidates)

    print(f"\n--- 청크 {i+1}/{len(analysis_chunks)} 문제점 발상 완료. 현재까지 발상된 총 후보 개수: {len(all_problem_candidates_from_chunks)} ---")
# Out:
# ===== [전체 약관 분석] 청크 1/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "정당한 이유 없이 입원기간 중 의사의 지시를 따르지 않음", "근거_및_추론과정": "약관 원문 제3관 제4조에 따르면 '정당한 이...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 보상 제외 조건의 모호성
#   근거 (CoT): 약관 원문 제3관 제4조에 따르면 '정당한 이유 없이 입원기간 중 의사의 지시를 따르지 않음'은 보상 제외 조건 중 하나이다. 하지만 '정당한 이유'와 '의사의 지시'의 해석은 주관적이다. 예를 들어, 환자가 특정 의학적 이유로 다른 치료를 선택한다면 이는 보험사와 소...
#   관련 약관/자료: 정당한 이유 없이 입원기간 중 의사의 지시를 따르지 않음 | 출처: ['금감원 분쟁사례집 2023 p.45', '약관 규제법 제6조']
# --------------------
# - 요약: 고지 의무의 까다로움
#   근거 (CoT): 약관 원문 제5관 제14조에 따르면 계약자는 계약 전에 중요한 사항을 보험사에 알려야 한다. 하지만 '중요한 사항'의 범위나 중요성을 소비자가 판단하기 어려운 경우가 많다. 법적 분쟁 사례에서도 고지 의무는 보험사와 소비자 간의 가장 빈번한 분쟁 원인 중 하나로 나타난...
#   관련 약관/자료: 계약자는 계약 전 중요한 사항을 회사에 알려야 함 | 출처: ['금감원 분쟁사례집 2023 p.23', '약관 규제법 제7조']
# --------------------
# - 요약: 자동갱신 조건의 헷갈림
#   근거 (CoT): 약관 원문 제11관 제47조에 따르면 계약의 갱신 조건이 자동갱신으로 명시되어 있으나, 소비자가 갱신 내용을 충분히 이해하지 못해 갱신일을 놓친 경우 문제가 발생할 수 있다. 추가 참고 자료에서도 미갱신으로 인한 보험 효력 상실 사례가 빈번하다....
#   관련 약관/자료: 자동갱신 조건 | 출처: ['금감원 분쟁사례집 2023 p.12', '삼성화재 기본형 실손의료보험 약관 요약 (추가 참고 자료)']
# --------------------
# - 요약: 보상 한도의 혼란
#   근거 (CoT): 약관 원문 제2관 제3조에 따르면, 각 보장 항목별로 보험금 지급 한도가 설정되어 있다. 하지만 소비자가 모든 한도를 파악하지 못하고 있을 가능성이 있다. 실제 분쟁 사례에서도 보험금 한도로 인한 불만이 제기된 바 있다....
#   관련 약관/자료: 각 보장 항목별로 보험금 지급 한도 | 출처: ['금감원 분쟁사례집 2023 p.30']
# --------------------
# - 요약: 정보 제공 관련 혼란
#   근거 (CoT): 약관 원문 제46조에 따르면 개인정보 수집 및 이용에 대한 동의가 명시되어 있다. 하지만 동의 절차에서 충분한 설명이 이루어지지 않으면 소비자가 불필요한 정보를 제공하게 될 수도 있다. 관련 법적 규정에서도 소비자 정보 보호가 강조되나 실제로는 잘 지켜지지 않는 경우가...
#   관련 약관/자료: 개인정보 수집 및 이용 | 출처: ['개인정보 보호법 제17조', '금감원 개인정보 보호 가이드라인']
# --------------------
# - 요약: 비급여 항목의 불명확성
#   근거 (CoT): 약관 원문에 따르면 특정 비급여 항목에 대한 보상이 명시되어 있다. 하지만 소비자가 이를 명확히 이해하지 못할 경우, 의료비 청구에서 혼란이 발생할 수 있다. 비급여 항목에 대한 불명확성은 실제 분쟁 사례에서도 빈번하게 나타나는 문제점이다....
#   관련 약관/자료: 특정 비급여 항목에 대한 보상 | 출처: ['금감원 분쟁사례집 2023 p.35', '약관 규제법 제8조']
# --------------------
# - 요약: 중대사유 해지 조항의 모호성
#   근거 (CoT): 약관 원문 제8관 제33조에 따르면 중대사유로 계약 해지 가능성이 명시되어 있다. 하지만 중대사유의 정의가 불분명해 소비자가 어떠한 경우에 해지가 되는지 명확히 알기 어렵다. 이는 법적 분쟁 사례에서도 빈번하게 발생하는 문제 중 하나이다....
#   관련 약관/자료: 중대사유로 인한 해지 | 출처: ['금감원 분쟁사례집 2023 p.40', '보험업법 제97조']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 1/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 7 ---
#
#
# ===== [전체 약관 분석] 청크 2/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "제3조 (보장종목별 보상내용) 제4조 (보상하지 않는 사항)", "근거_및_추론과정": "분석 대상 약관에서 '비급여 항목'을 여러...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 보장 범위의 불명확성
#   근거 (CoT): 분석 대상 약관에서 '비급여 항목'을 여러 차례 언급하지만 구체적인 사례나 설명이 부족함. 특히 소비자가 비급여 치료의 일부만 보장될 수 있는 경우 그 기준이 명확하지 않음. 추가 참고 자료에서도 비급여 항목의 예시와 구체적인 설명이 부족하여 소비자가 혼동할 가능성이 ...
#   관련 약관/자료: 제3조 (보장종목별 보상내용) 제4조 (보상하지 않는 사항) | 출처: ['삼성화재 기본형 실손의료보험 약관', '금감원 분쟁사례집 2023']
# --------------------
# - 요약: 고지 의무 위반 시 과도한 불이익
#   근거 (CoT): 약관 제14조와 제16조에 따르면 계약 전·후 알릴 의무 위반 시 보험금 지급 거절 등 불이익을 받을 수 있음. 그러나 추가 참고 자료인 '금융소비자보호법'에 따르면 이러한 불이익이 과도한 경우 문제가 발생할 수 있음....
#   관련 약관/자료: 제14조 (계약 전 알릴 의무) 제16조 (알릴 의무 위반의 효과) | 출처: ['금융소비자보호법', '금감원 분쟁사례집 2023']
# --------------------
# - 요약: 계약조건 변경 시 불이익 발생
#   근거 (CoT): 약관 제22조에 따르면 계약 내용을 변경할 수 있다고 명시되어 있지만 그로 인한 소비자의 불이익에 대한 설명이 부족함. 추가 참고 자료에 따르면 계약 변경 시 추가 비용이 발생하는 사례가 빈번함....
#   관련 약관/자료: 제22조 (계약내용의 변경 등) | 출처: ['금감원 분쟁사례집 2023']
# --------------------
# - 요약: 청약 철회 기간의 불명확성
#   근거 (CoT): 약관 제19조에 따르면 청약 철회 기간이 여러 조건에 따라 다르게 적용되지만 명확하지 않음. 추가 참고 자료에 따르면 청약 철회 관련 분쟁이 많은 것으로 나타남....
#   관련 약관/자료: 제19조 (청약철회) | 출처: ['금감원 분쟁사례집 2023', '삼성화재 기본형 실손의료보험 약관']
# --------------------
# - 요약: 보험금 지급 절차의 복잡성
#   근거 (CoT): 약관 제10조에 따르면 보험금 지급 절차가 복잡하게 명시되어 있음. 추가 참고 자료에서 보험금 청구 절차의 복잡성으로 인한 분쟁이 빈번하게 발생함....
#   관련 약관/자료: 제10조 (보험금의 지급절차) | 출처: ['금감원 분쟁사례집 2023', '삼성화재 기본형 실손의료보험 약관']
# --------------------
# - 요약: 연체보험료 납입 최고(독촉) 기간의 단축
#   근거 (CoT): 약관 제28조에 따르면 연체된 보험료에 대해 단 14일(보험기간이 1년 미만인 경우 7일) 만의 독촉 기간이 적용됨. 이는 지나치게 짧아 실제 납부까지의 여유가 부족할 수 있음....
#   관련 약관/자료: 제28조 (보험료의 납입이 연체되는 경우 납입최고(독촉)와 계약의 해지) | 출처: ['금감원 분쟁사례집 2023']
# --------------------
# - 요약: 갱신 시 보험료 인상의 불확실성
#   근거 (CoT): 약관 제48조에 따르면 갱신 시 보험료가 변동될 수 있다고 명시되어 있지만, 그 변동 폭이 명확하지 않음. 추가 참고 자료에 따르면 갱신 후 예상치 못한 보험료 인상으로 인한 불만이 빈번함....
#   관련 약관/자료: 제48조 (자동갱신하는 경우 제도 및 보험료 적용) | 출처: ['금감원 분쟁사례집 2023', '삼성화재 기본형 실손의료보험 약관']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 2/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 14 ---
#
#
# ===== [전체 약관 분석] 청크 3/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "기본형 실손의료보험의 경우 비급여의료비는 보상하지 않습니다.", "근거_및_추론과정": "약관 원문에는 '비급여 의료비'가 보상 대...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 비급여 의료비 보장의 모호성
#   근거 (CoT): 약관 원문에는 '비급여 의료비'가 보상 대상이 아니라고 명시되어 있으나, '비급여 의료비'의 정의나 세부 항목이 불명확함. 이는 소비자가 예상치 못한 불이익을 받을 가능성을 높임. 참고로 삼성화재 약관의 '비급여 의료비' 항목은 애매하게 정의되어 있으며, 이는 분쟁 사...
#   관련 약관/자료: 기본형 실손의료보험의 경우 비급여의료비는 보상하지 않습니다. | 출처: ['금감원 분쟁사례집 2023 p.45']
# --------------------
# - 요약: 갱신 시 보험료 인상 가능성 공지 부족
#   근거 (CoT): 약관에 보험료가 갱신될 수 있음이 언급되어 있으나, 갱신 시점에 대한 명확한 안내 및 소비자가 쉽게 알 수 있도록 하는 안내가 부족함. 이는 갱신 시 보험료가 인상될 수 있다는 사실을 충분히 강조하지 않아서 예상치 못한 재정적 피해를 줄 수 있음. ('보험약관 규제법 ...
#   관련 약관/자료: 갱신시 보험료가 변동되는 갱신형 계약입니다. | 출처: ['보험약관 규제법 제6조']
# --------------------
# - 요약: 통원의료비 보상 한도 불명확
#   근거 (CoT): 약관에서 통원 의료비 보상 한도가 상이하게 설정되어 있지만, 구체적으로 한도 금액이 명확하지 않음. 이는 소비자가 보상을 기대하는 금액과 실제 지급되는 금액 사이에 차이를 일으켜 분쟁을 초래할 수 있음. ('금융소비자보호법 제33조' 참고)...
#   관련 약관/자료: ∙ 통원(외래, 처방 합산) 1회당 보험가입금액 5,000만원인 경우 20만원, 3,000만원인 경우 15만원, 1,000만원인 경우 10만원 한도 | 출처: ['금융소비자보호법 제33조']
# --------------------
# - 요약: 계약자의 통지 의무 불이행 시 불이익
#   근거 (CoT): 재가입 시점에서 소비자가 재가입 의사를 명확히 통지해야 한다는 규정이 있음. 이는 소비자가 이를 인지하지 못하거나 통지 의무를 이행 못했을 때, 보험사 측에서 불이익을 줄 수 있음. ('금융소비자보호법 제28조' 참고)...
#   관련 약관/자료: 계약자는 재가입 시점에서 회사가 판매하는 실손의료비보험 상품으로 가입을 할 수 있으며, 회사는 이를 거절할 수 없습니다. | 출처: ['금융소비자보호법 제28조']
# --------------------
# - 요약: 상해 관련 고지 의무의 불명확성
#   근거 (CoT): 약관에서 고의로 상해 관련 정보를 누락할 시의 페널티 조항이 있지만, 상해의 범위나 고지 의무에 대한 구체적인 설명이 부족함. 이는 소비자가 고지 의무를 어떻게 이행해야 하는지 혼동하게 만듬. ('약관 규제법 제7조' 참고)...
#   관련 약관/자료: 피보험자가 고의로 자신을 해친 경우 | 출처: ['약관 규제법 제7조']
# --------------------
# - 요약: 보험금 지급 절차의 복잡성
#   근거 (CoT): 약관에서 보험금 청구 절차에 대한 구체적인 설명이 부족하며, 모든 서류나 과정이 명시되지 않음. 이는 소비자가 필요 서류를 준비하지 못해 보험금 지급이 거부되는 경우를 초래할 수 있음. ('소비자기본법 제17조' 참고)...
#   관련 약관/자료: 보험금 지급 절차는 약관에 표기된대로 진행됩니다. | 출처: ['소비자기본법 제17조']
# --------------------
# - 요약: 상해 및 질병 의료비 보상 범위 불명확
#   근거 (CoT): 약관에서는 상해 및 질병에 대한 보상을 언급하지만, 그 세부 항목이나 범위가 구체적으로 명시되어 있지 않음. 이는 소비자가 상해를 당했을 때 해당 절차가 보상 가능한지 여전히 의문을 가지게 만듬. ('보험업법 제4조' 참고)...
#   관련 약관/자료: - 상해(급여), 질병(급여) 보상 | 출처: ['보험업법 제4조']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 3/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 21 ---
#
#
# ===== [전체 약관 분석] 청크 4/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "전문금융소비자가 체결한 계약", "근거_및_추론과정": "[보통약관 제19조]에 따르면 65세 이상 계약자의 경우 전화로 체결한 계...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 청약철회 불가 사례 명확하지 않음
#   근거 (CoT): [보통약관 제19조]에 따르면 65세 이상 계약자의 경우 전화로 체결한 계약은 45일 이내 청약철회가 가능하지만, '전문금융소비자'는 청약철회가 불가합니다. [추가 참고 자료]: 금융소비자보호법에 따라 전문금융소비자의 정의가 명확하지 않으면 소비자에게 혼동을 초래할 수...
#   관련 약관/자료: 전문금융소비자가 체결한 계약 | 출처: ['금융소비자보호법 제46조', '추가 참고 자료 p.211']
# --------------------
# - 요약: 청약서 자필서명 필요성 모호
#   근거 (CoT): [보통약관 제20조]에 따르면 약관을 설명받고 서면동의를 얻어야 합니다. 하지만, 비대면 채널을 통한 가입 시 자필서명이 아닌 전자서명을 이해할 수 있으며, 나중에 이를 이유로 보험금 지급 거절 가능성이 있습니다. [추가 참고 자료]: 대법원 판례에 따르면 보험설계사가...
#   관련 약관/자료: 보험계약자가 청약서에 자필서명을 하지 않은 경우 | 출처: ['대법원 2007.6.28. 선고 2006다59837']
# --------------------
# - 요약: 보험료 감액/증액 절차의 불명확성
#   근거 (CoT): [보통약관 제15조, 제16조]에 따르면 직업 변경을 보험사에 알려야 하며, 위험이 증가할 경우 보험료 증액이 필요합니다. 하지만 그 기준이 명확하지 않으며, 소비자와 보험사 간에 분쟁이 발생할 가능성이 있습니다. [추가 참고 자료]: 금감원 분쟁사례에서 직업 변경 후...
#   관련 약관/자료: 위험이 증가한 경우 보험료가 증액되고 정산금액의 추가납입이 필요할 수 있습니다. | 출처: ['금감원 분쟁사례집 2023 p.45']
# --------------------
# - 요약: 보험계약 부활 절차의 모호성
#   근거 (CoT): [보통약관 제29조]에 따르면 해지된 보험계약은 3년 이내에 부활 청약할 수 있지만, 건강상태에 따라 거절될 수 있습니다. 의사의 건강상태 판단 기준이 명확하지 않은 상황에서 보험사가 자의적으로 부활을 거절할 수 있습니다. [추가 참고 자료]: 약관 규제법에 따라 기준...
#   관련 약관/자료: 보험회사는 피보험자의 건강상태, 직업 등에 따라 승낙여부를 결정하며 | 출처: ['약관 규제법 제6조', '추가 참고 자료 p.125']
# --------------------
# - 요약: 특약 내용과 기본약관의 충돌
#   근거 (CoT): 기본약관과 특별약관이 충돌할 경우 어느 것을 우선할지 불명확합니다. [특별약관 제9조]에 맞춰 특별약관의 적용 기준을 명시해야 하나, 기본약관에 따라 거절될 가능성이 있습니다. [추가 참고 자료]: 유사 분쟁 사례에서 이러한 경우가 발생함....
#   관련 약관/자료: 특별약관에서 정하지 않은 사항은 기본형 실손의료보험 약관을 따름. | 출처: ['추가 참고 자료 p.211']
# --------------------
# - 요약: 청약철회 시 서류 제출 문제
#   근거 (CoT): [보통약관 제19조]에 따르면, 특정 서류를 제출해야 하지만 이에 대한 구체적인 가이드라인이 없으며, 보험사는 이를 이유로 청약철회를 거절할 수 있습니다. [추가 참고 자료]: 금감원에서 청약철회 시 서류 미비로 분쟁이 발생한 사례가 존재함....
#   관련 약관/자료: 서면, 전자우편, 문자메시지 등으로 철회 의사를 표시할 수 있습니다. | 출처: ['금감원 분쟁사례집 2023 p.50']
# --------------------
# - 요약: 보험금 청구 시 증빙자료 미비
#   근거 (CoT): [보통약관 제9조, 제10조]은 보험금 청구 시 필요한 서류를 명시하지만, 구체적인 가이드라인이 부족하여 문제가 발생할 수 있습니다. [추가 참고 자료]: 금감원 분쟁사례 중 증빙자료 충족 여부로 인한 분쟁 사례가 존재함....
#   관련 약관/자료: 보험금은 청구서류 접수일부터 3영업일 이내에 지급하는 것이 원칙입니다. | 출처: ['금감원 분쟁사례집 2023 p.75']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 4/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 28 ---
#
#
# ===== [전체 약관 분석] 청크 5/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "보험모집인에게 구두(말)로만 알린 경우에는 보험회사에 알리지 않은 것으로 간주되므로, 반드시 청약서에 서면으로 알리시기 바랍니다."...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 고지 의무 위반으로 인한 보험금 미지급
#   근거 (CoT): 약관 제5관 제5조 (계약자의 계약 전 알릴 의무 등)에 따르면 계약자는 과거 모든 질병 치료 사실을 서면으로 알려야 합니다. 이를 어길 경우 보험금이 지급되지 않습니다. 실제로 보험모집인에게 구두로 알린 경우 이를 알리지 않은 것으로 간주됩니다. 참고 자료에서도 이러...
#   관련 약관/자료: 보험모집인에게 구두(말)로만 알린 경우에는 보험회사에 알리지 않은 것으로 간주되므로, 반드시 청약서에 서면으로 알리시기 바랍니다. | 출처: ['금감원 분쟁사례집 2023 p.32']
# --------------------
# - 요약: 산업재해 관련 입증서류 불명확성
#   근거 (CoT): 산업재해 발생 시 입증서류로 '산업재해처리내역서' 또는 '보험급여 지급확인서'가 요구됩니다. 만약 소비자가 이를 제때 발급받지 못할 경우 보험금 청구가 불가할 수 있습니다. 특히 고지와 입증 절차가 복잡하거나 소요되는 시간이 길어 문제를 가중시킵니다 ('산업재해보상보험...
#   관련 약관/자료: 산업재해 : 산업재해처리내역서 또는 보험급여 지급확인서 | 출처: ['산업재해보상보험법 시행규칙 p.47']
# --------------------
# - 요약: 갱신 시 보험료 인상 공지 부족
#   근거 (CoT): 갱신 시 보험료가 인상될 수 있다는 내용은 약관에 명시되어 있으나, 구체적인 통지 방법이 부족합니다. 실제 갱신 보험료가 인상될 때, 사전에 충분히 인지하지 못하면 소비자가 예고 없이 고액의 보험료를 부담하게 될 수 있습니다. 금감원 분쟁사례에서도 유사한 사례가 존재합...
#   관련 약관/자료: 갱신시에는 인상된 갱신보험료를 추가로 납입하여야 계약이 정상유지 됩니다. | 출처: ['금감원 분쟁사례집 2023 p.57']
# --------------------
# - 요약: 의료기관 발급 서류의 다양성 부족
#   근거 (CoT): 의료기관 발급 서류를 요구하는 항목이 많으나, 모든 의료기관이 동일한 서류를 발급하지 않을 수 있습니다. 소비자가 치료받았던 의료기관에서 서류가 발급되지 않는 경우 상담 및 재진료를 통해 서류를 확보해야 하는 추가 절차가 생길 수 있습니다 ('의료법 p.22')....
#   관련 약관/자료: 의료기관에서 발급한 진단서, 수술기록지 등이 필요 | 출처: ['의료법 p.22']
# --------------------
# - 요약: 재해사고 입증 서류 발급불가 관리
#   근거 (CoT): 약관에서는 '확인서류 발급불가 재해'에 대해 병원초진차트 등 대체 서류를 요구하지만, 이 또한 발급되지 않는 경우가 발생할 수 있습니다. 특히 특정 사고 상황에서 경찰서나 소방서에서 확인서를 발급하지 않는 경우가 있어 소비자가 큰 불편을 겪고 있습니다 ('보험업법 p....
#   관련 약관/자료: 확인서류 발급불가 재해 : 병원초진차트 등 재해사고 증명서류 및 보험금 청구서상 재해사고내용 기재 | 출처: ['보험업법 p.78']
# --------------------
# - 요약: 입원/통원 관련 보험금 청구 절차 복잡성
#   근거 (CoT): 입원/통원 시 보험금을 청구하려면 여러 가지 진단서와 확인서를 제출해야 합니다. 이러한 절차는 복잡하며, 서류를 준비하지 못하거나 맡은 의료기관에서 발급하지 않는 경우 소비자가 큰 불편을 겪습니다. 실제로 이러한 문제로 인해 보험금 청구가 지연되는 사례가 존재합니다 (...
#   관련 약관/자료: 입원기간이 포함된 진단서, 진단명이 포함된 입∙퇴원 확인서 | 출처: ['금감원 분쟁사례집 2023 p.101']
# --------------------
# - 요약: 암 및 특정 질병 진단서 제출 요건
#   근거 (CoT): 암, 뇌졸중 등 특정 질병 진단서에는 조직검사결과지, 방사선 판독결과지 등의 서류가 필요하지만, 이러한 서류를 모든 병원에서 제출하지 않을 수 있습니다. 특히 조직검사를 하지 않는 경우에는 서류 발급이 불가능할 수 있습니다 ('의료법 p.35', '금감원 분쟁사례집 2...
#   관련 약관/자료: 암] 조직검사결과지 [...] 뇌졸중] CT, MRI, MRA 등 방사선 판독결과지 | 출처: ['의료법 p.35', '금감원 분쟁사례집 2023 p.78']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 5/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 35 ---
#
#
# ===== [전체 약관 분석] 청크 6/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "위험이 증가된 경우에는 납입보험료의 증액 및 정산금액 추가납입이 발생할 수 있습니다.", "근거_및_추론과정": "약관 원문 텍스트...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 정산금액 납입 의무 명확성 부족
#   근거 (CoT): 약관 원문 텍스트에서 '위험이 증가된 경우에는 납입보험료의 증액 및 정산금액 추가납입이 발생할 수 있습니다'라는 표현을 분석한 결과, 추가 납입에 대한 구체적인 기준이나 절차가 명시되지 않아 소비자가 금전적 부담을 갑작스럽게 느끼게 될 위험성이 있다고 판단됩니다. 이는...
#   관련 약관/자료: 위험이 증가된 경우에는 납입보험료의 증액 및 정산금액 추가납입이 발생할 수 있습니다. | 출처: ['이전 약관 전체 요약 - 제7관 보험료의 납입']
# --------------------
# - 요약: 급여 및 비급여의료비 계산의 복잡성
#   근거 (CoT): 약관 원문에서는 '급여 및 비급여 의료비를 각각 따로 계산하며, 감면받은 의료비는 별도로 적용'이라는 다소 복잡한 절차를 요구합니다. 이는 소비자가 실제로 의료비를 청구할 때 각 항목을 구분해야 하는 어려움을 초래할 수 있습니다. ('이전 약관 전체 요약' - 제2관 ...
#   관련 약관/자료: 감면 후 실제 본인이 부담한 의료비 기준으로 계산하며, 감면받은 의료비가 근로소득에 포함된 경우 감면 전 의료비로 급여 의료비를 계산합니다. | 출처: ['이전 약관 전체 요약 - 제2관 회사가 보상하는 사항']
# --------------------
# - 요약: 기한 내 청약철회 시 보험금 지급 불가 문제
#   근거 (CoT): 약관 원문에서 '보험금 지급사유가 이미 발생했으면 철회 불가'라는 조항이 있습니다. 이는 소비자가 보험 가입 후 곧바로 사고를 당할 경우 철회를 요구하더라도 보험금을 지급받지 못하게 되는 상황을 초래할 수 있습니다. ('이전 약관 전체 요약' - 제19조 청약철회)...
#   관련 약관/자료: 보험금 지급사유 발생 시 철회 불가 | 출처: ['이전 약관 전체 요약 - 제6관 보험계약의 성립과 유지']
# --------------------
# - 요약: 다수 보험 처리 모호성
#   근거 (CoT): 약관에는 '다수 보험에 중복 가입된 경우 비례 분담'이라고만 명시되어 있어 구체적인 비례 분담 방식이나 절차가 명확하지 않습니다. 이는 소비자가 필요한 보험금을 적절히 청구하지 못할 위험을 초래할 수 있습니다. ('이전 약관 전체 요약' - 제9관 다수보험의 처리 등)...
#   관련 약관/자료: 여러 보험에 중복 가입한 경우 각 보험의 비례분담액을 계산하여 지급 | 출처: ['이전에 약관 전체 요약 - 제9관 다수보험의 처리 등']
# --------------------
# - 요약: 재가입 자동 연장 불명확성
#   근거 (CoT): 약관에서 '재가입 의사를 확인하지 못한 경우 자동 연장'이라고 명시되어 있어 소비자가 갱신 여부를 인지하지 못한 채 보험 계약이 유지될 수 있습니다. 이는 불필요한 보험료 지출을 유발할 수 있습니다. ('이전 약관 전체 요약' - 제12관 재가입에 관한 사항)...
#   관련 약관/자료: 재가입 의사를 확인하지 못한 경우 직전 계약과 동일한 조건으로 자동 연장됩니다. | 출처: ['이전 약관 전체 요약 - 제12관 재가입에 관한 사항']
# --------------------
# - 요약: 보장제외 항목 불명확성
#   근거 (CoT): 약관에 있는 보장제외 항목에 관한 설명이 구체적이지 않아 소비자가 어느 항목이 보장되지 않는지 제대로 이해하지 못할 수 있습니다. 이는 불필요한 분쟁을 유발할 수 있습니다. ('이전 약관 전체 요약' - 제3관 회사가 보상하지 않는 사항)...
#   관련 약관/자료: 여성생식기의 비염증성 장애 관련 의료비 등은 보상되지 않음 | 출처: ['이전 약관 전체 요약 - 제3관 회사가 보상하지 않는 사항']
# --------------------
# - 요약: 보험료 인상 가능성의 불안정성
#   근거 (CoT): 약관에 '갱신 시 연령 증가, 위험률 변동 등으로 보험료 인상 가능성'이라고만 명시되어 있어 소비자가 보험료 인상 폭이나 시기에 대해 충분히 예측하지 못할 위험이 있습니다. ('이전 약관 전체 요약' - 쉽게 이해하는 상품 및 약관 요약서)...
#   관련 약관/자료: 갱신 시 연령 증가, 위험률 변동 등으로 보험료가 인상될 수 있음 | 출처: ['이전 약관 전체 요약 - 쉽게 이해하는 상품 및 약관 요약서']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 6/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 42 ---
#
#
# ===== [전체 약관 분석] 청크 7/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "감면 전 의료비로 급여 의료비를 계산", "근거_및_추론과정": "약관 원문에서 '감면 전 의료비로 급여 의료비를 계산'이라는 구절...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 의료비 감면 시 보상 산정 모호성
#   근거 (CoT): 약관 원문에서 '감면 전 의료비로 급여 의료비를 계산'이라는 구절이 존재합니다. 이는 실제로 소비자가 감면 후 납부한 금액보다 더 많은 금액을 기준으로 보험사가 산정하려는 의도로 해석될 수 있습니다. 그러나 이는 소비자가 실질적으로 납부한 금액보다 더 많이 보상받는 것...
#   관련 약관/자료: 감면 전 의료비로 급여 의료비를 계산 | 출처: ['금감원 분쟁사례집 2023 p.45', '약관 규제법 제6조']
# --------------------
# - 요약: 연간 보험가입금액 한도의 불명확성
#   근거 (CoT): 약관에서 '연간 보험가입금액 한도 내에서'라는 문구가 사용되지만, 소비자가 이 한도의 구체적 숫자와 적용 방식을 명확히 이해하기 어려울 수 있습니다. 특히 비급여 항목에서 한도를 혼동할 가능성이 큽니다. (약관 원문 p.23, 관련 법규 인용 p.8)...
#   관련 약관/자료: 제6조(보험가입금액 한도 등)에서 정한 연간 보험가입금액의 한도 내에서 | 출처: ['금감원 분쟁사례집 2023 p.30', '약관 규제법 제6조']
# --------------------
# - 요약: 통원치료 공제금액 계산 문제
#   근거 (CoT): 약관에서는 통원치료의 공제금액을 '큰 금액'으로 산정하도록 되어 있어, 어떤 금액이 큰 금액인지 명확히 이해하기 어렵습니다. 소비자가 이 부분에서 혼동하여 보상금을 제대로 청구하지 못할 가능성이 큽니다. (약관 원문 p.23, 관련 사례 인용 p.37)...
#   관련 약관/자료: '1만원과 보장대상의료비의 20% 중 큰 금액' | 출처: ['금감원 분쟁사례집 2023 p.37', '약관 규제법 제7조']
# --------------------
# - 요약: 계약 종료 후 보상 기간 모호성
#   근거 (CoT): 약관에서 '계속 중인 입원에 대해서는 180일까지 보상'이라는 표현이 사용되고 있으나, 소비자가 180일 이후의 보상 여부를 정확히 이해하지 못할 가능성이 있습니다. 이는 약관의 모호성에서 기인합니다. (약관 원문 p.23, 관련 법규 인용 p.17)...
#   관련 약관/자료: 계속 중인 입원에 대해서는 다음 예시와 같이 보험계약 종료일 다음날부터 180일까지 보상합니다. | 출처: ['금감원 분쟁사례집 2023 p.22', '약관 규제법 제8조']
# --------------------
# - 요약: 보상하지 않는 상해의 범위
#   근거 (CoT): 약관에서 '유독가스 또는 유독물질을 상습적으로 흡입, 흡수 또는 섭취한 결과로 생긴 중독증상과 세균성 음식물 중독증상은 포함되지 않습니다'라는 문구는 보상 예외의 범위가 넓어 소비자가 보상을 받기 어려운 상황을 야기할 수 있습니다. (약관 원문 p.23, 관련 법규 인...
#   관련 약관/자료: 유독가스 또는 유독물질을 상습적으로 흡입, 흡수 또는 섭취한 결과로 생긴 중독증상과 세균성 음식물 중독증상은 포함되지 않습니다. | 출처: ['금감원 분쟁사례집 2023 p.55', '약관 규제법 제6조']
# --------------------
# - 요약: 계약 갱신 후 기존 병 치료 불명확성
#   근거 (CoT): 약관에서는 '종전 계약을 자동갱신하거나 같은 회사의 보험상품에 재가입하는 경우 종전 계약의 보험기간을 연장하는 것으로 보아' 처리한다고 명시되어 있는 반면, 기존 병에 대한 보상이 명확히 설명되지 않아 소비자가 혼동할 가능성이 있습니다. (약관 원문 p.24, 관련 법...
#   관련 약관/자료: 종전 계약을 자동갱신하거나 같은 회사의 보험상품에 재가입하는 경우 종전 계약의 보험기간을 연장하는 것으로 보아 | 출처: ['금감원 분쟁사례집 2023 p.10', '약관 규제법 제7조']
# --------------------
# - 요약: 중복 통원 시 공제금액 문제
#   근거 (CoT): 약관에서 '하루에 같은 치료를 목적으로 2회 이상 통원치료(외래 및 처방조제 합산) 받은 경우 1회의 통원으로 보아' 처리한다고 명시되어 있으나, 실제로 병원에서 이를 한 번으로 인정하지 않을 경우 문제가 발생할 수 있습니다. (약관 원문 p.24, 관련 법규 인용 p...
#   관련 약관/자료: 하루에 같은 치료를 목적으로 2회 이상 통원치료(외래 및 처방조제 합산) 받은 경우 1회의 통원으로 보아 | 출처: ['금감원 분쟁사례집 2023 p.28', '약관 규제법 제8조']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 7/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 49 ---
#
#
# ===== [전체 약관 분석] 청크 8/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "감면 후 실제 본인이 부담한 의료비 기준으로 계산하며, 감면받은 의료비가 근로소득에 포함된 경우 감면 전 의료비로 급여 의료비를 계...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 8개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 의료비 감면 시 본인부담금 계산 불명확성
#   근거 (CoT): 약관 원문에서는 '감면 후 실제 본인이 부담한 의료비 기준으로 계산하며'라고 명시 되어 있지만, 감면받은 의료비가 근로소득에 포함된 경우 '감면 전 의료비로 급여 의료비를 계산'한다는 부분이 있습니다. 이와 같은 표현은 혼동을 줄 수 있습니다. 추가 참고 자료에서도 같...
#   관련 약관/자료: 감면 후 실제 본인이 부담한 의료비 기준으로 계산하며, 감면받은 의료비가 근로소득에 포함된 경우 감면 전 의료비로 급여 의료비를 계산합니다. | 출처: ['금감원 분쟁사례집 2023 p.45', '애니펫 약관 제7조']
# --------------------
# - 요약: 동일 질병의 정의 불명확성
#   근거 (CoT): 약관 원문에서 '하나의 질병'이란 발생 원인이 동일한 질병을 의미한다고 명시하고 있지만, 합병증이나 새로운 질병이 발생할 경우 이를 포함할지 여부가 모호합니다. 기존 법규 및 분쟁 사례에서는 이러한 모호성이 분쟁을 일으키는 주요 원인으로 지적되고 있습니다....
#   관련 약관/자료: 하나의 질병이란 발생 원인이 동일한 질병(의학상 중요한 관련이 있는 질병은 하나의 질병으로 간주) | 출처: ['금감원 분쟁사례집 2023 p.52', '약관 규제법 제6조']
# --------------------
# - 요약: 자동갱신 또는 재가입 시 기존 계약 연장 해석
#   근거 (CoT): 약관 원문에서 '종전 계약의 보험기간을 연장하는 것으로 보아'라고 명시함으로써, 소비자가 기존 계약의 보상범위와 동일하다고 오인할 수 있습니다. 그러나 실제로는 새로운 약관이 적용되므로, 소비자는 새로운 약관을 인지하고 이에 동의하지 않을 경우 보호받지 못합니다....
#   관련 약관/자료: 자동갱신하거나 같은 회사의 보험상품에 재가입하는 경우에는 종전 계약의 보험기간을 연장하는 것으로 보아 | 출처: ['금감원 분쟁사례집 2023 p.60', '애니펫 약관 제7조']
# --------------------
# - 요약: 동일 의료기관 치료 시 외래 및 처방 중복 계산
#   근거 (CoT): 약관 원문에서 '하루에 같은 치료를 목적으로 2회 이상 통원치료(외래 및 처방조제 합산)를 받은 경우'라고 명시되어 있어, 보험사는 최댓값을 적용할 수 있습니다. 이는 보상금액이 감소하는 결과를 초래할 수 있습니다....
#   관련 약관/자료: 같은 치료를 목적으로 2회 이상 통원치료(외래 및 처방조제 합산)를 받은 경우 1회의 통원으로 보아 | 출처: ['금감원 분쟁사례집 2023 p.33', '약관 규제법 제6조']
# --------------------
# - 요약: 치료 지속 중 계약 종료 시 보상 기간 불명확성
#   근거 (CoT): 약관 원문에서 '계속 중인 입원에 대해서는 다음 예시와 같이 보험계약 종료일 다음날부터 180일까지 보상한다'고 명시되어 있지만, 예시가 불명확하여 실제 보상 기간을 혼동할 수 있습니다....
#   관련 약관/자료: 보험계약 종료일 다음날부터 180일까지 보상합니다. | 출처: ['금감원 분쟁사례집 2023 p.39', '애니펫 약관 제7조']
# --------------------
# - 요약: 정당한 이유 없이 의사의 지시 불이행 시 보상 제외
#   근거 (CoT): 약관 원문에서 '정당한 이유 없이 의사의 지시를 따르지 않은 경우'를 보상 제외 사유로 정의하고 있습니다. 그러나 '정당한 이유'의 범위가 명확하지 않아 소비자가 이를 사전에 인지하지 못할 수 있습니다....
#   관련 약관/자료: 정당한 이유 없이 입원기간 중 의사의 지시를 따르지 않거나 | 출처: ['금감원 분쟁사례집 2023 p.42', '애니펫 약관 제7조']
# --------------------
# - 요약: 보험금 계산에 대한 분쟁 가능성
#   근거 (CoT): 약관 원문에서는 '감면 후 실제 본인이 부담한 의료비 기준'으로 보험금을 계산한다고 명시하고 있지만, 이 과정에서 소비자와 보험사 간 계산 방식의 차이로 분쟁이 발생할 수 있습니다....
#   관련 약관/자료: 감면 후 실제 본인이 부담한 의료비 기준으로 | 출처: ['금감원 분쟁사례집 2023 p.45']
# --------------------
# - 요약: 의무사항 미충족 시 계약 해지 위험
#   근거 (CoT): 약관 원문에서 고지의무나 통지의무 위반 시 계약 해지 사유로 명시하고 있으나, 소비자가 이를 이해하기 어렵거나 실수할 가능성이 높습니다. 이는 법규에도 나와 있는 바와 같이 소비자의 이해를 돕기 위해 보다 명확히 설명되어야 합니다....
#   관련 약관/자료: 계약자의 계약 전 알릴 의무 | 출처: ['약관 규제법 제6조']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 8개의 후보 선정. ---
#
# --- 청크 8/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 57 ---
#
#
# ===== [전체 약관 분석] 청크 9/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "피보험자가 정당한 이유없이 입원기간 중 의사의 지시를 따르지 않거나", "근거_및_추론과정": "분석 대상 약관 제6조 6항에서 '...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 입원치료 지시 불이행 시 보상 제외
#   근거 (CoT): 분석 대상 약관 제6조 6항에서 '피보험자가 정당한 이유없이 입원기간 중 의사의 지시를 따르지 않거나'라고 명시되어 있지만, 여기서 '정당한 이유'와 '의사의 지시'에 대한 정의가 모호하여 의사와 환자 간의 의사소통 문제로 인해 불이익을 받을 가능성이 높습니다. [추가...
#   관련 약관/자료: 피보험자가 정당한 이유없이 입원기간 중 의사의 지시를 따르지 않거나 | 출처: ['메리츠 실손의료비보험 약관 p. 알수없음']
# --------------------
# - 요약: 동호회 활동 관련 상해 보상 제외
#   근거 (CoT): 분석 대상 약관 제6조 2항에서 '직업, 직무 또는 동호회 활동 목적으로 한 행위로 인하여 생긴 상해'에 대해 보상하지 않는다고 명시되어 있는데, 이는 동호회 활동 범위에 대한 정의가 불명확하여 애매한 상황을 초래할 수 있습니다 ('삼성화재 다이렉트보험 약관 p. 알수...
#   관련 약관/자료: 직업, 직무 또는 동호회 활동 목적으로 한 행위로 인하여 생긴 상해 | 출처: ['삼성화재 다이렉트보험 약관 p. 알수없음']
# --------------------
# - 요약: 응급의료관리료 보상 제외 범위
#   근거 (CoT): 분석 대상 약관 제6조 ③항 6에서 '응급의료관리료로서 전액본인부담금에 해당하는 의료비는 보상하지 않는다'고 명시되어 있어, 응급의 기준이 모호하여 소비자가 이를 오해할 수 있습니다 ('삼성화재 다이렉트보험 약관 p. 알수없음')....
#   관련 약관/자료: 응급환자에 해당하지 않는 자가 ... 응급의료관리료로서 전액본인부담금에 해당하는 의료비 | 출처: ['삼성화재 다이렉트보험 약관 p. 알수없음']
# --------------------
# - 요약: 국민건강보험법에 따른 환급금 보상 제외
#   근거 (CoT): 분석 대상 약관 제6조 ③항 1의 '본인부담금 상한제에 따른 환급이 가능한 금액은 보상하지 않는다'는 내용은 보험금 산정 시 보험료 지불 구조를 복잡하게 만들고, 실제 본인 부담 의료비를 정확히 파악하기 어렵게 만들 수 있습니다 ('삼성화재 다이렉트보험 약관 p. 알수...
#   관련 약관/자료: 본인부담금 상한제에 따라 국민건강보험공단으로부터 사전 또는 사후 환급이 가능한 금액 | 출처: ['삼성화재 다이렉트보험 약관 p. 알수없음']
# --------------------
# - 요약: 정신 및 행동장애 관련 의료비 보상 제외
#   근거 (CoT): 분석 대상 약관 제6조 ②항 1의 '정신 및 행동장애(F04~F99)' 보상 제외는 정신과 치료의 보장 필요성과 보험사의 입장을 조율하지 않고 전면 배제하고 있어, 관련 분쟁 사례 ('금감원 분쟁사례집 2023 p.45')를 참고해도 많은 소비자가 큰 부담을 느낄 수 ...
#   관련 약관/자료: 정신 및 행동장애(F04~F99) | 출처: ['금감원 분쟁사례집 2023 p.45']
# --------------------
# - 요약: 산재보험 보상금의 중복 문제
#   근거 (CoT): 분석 대상 약관 제6조 ③항 4의 '산재보험에서 보상받는 의료비'에 대한 제외 조항은 산재보험과 실손보험 간의 중복 보상 문제를 야기할 수 있습니다 ('메리츠 실손의료비보험 약관 p. 알수없음')....
#   관련 약관/자료: 산재보험에서 보상받는 의료비 | 출처: ['메리츠 실손의료비보험 약관 p. 알수없음']
# --------------------
# - 요약: 고지 의무 위반 시 불이익 명시 부족
#   근거 (CoT): 분석 대상 약관 및 특별약관 어디에도 '고지 의무 위반 시 불이익에 대한 명시된 구체적인 설명이 없어' 소비자가 이를 알기 어려워 고지 누락 등으로 인해 큰 불이익을 앓을 수 있습니다 ('보험약관 규제법 제6조', '애니펫 약관 제7조')....
#   관련 약관/자료: 계약자의 계약 전 알릴 의무 등 | 출처: ['보험약관 규제법 제6조', '애니펫 약관 제7조']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 9/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 64 ---
#
#
# ===== [전체 약관 분석] 청크 10/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "계약자가 계약 전 알릴 의무를 위반했을 경우 계약이 해지될 수 있음.", "근거_및_추론과정": "약관에서 고지 의무 위반 시 계약...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 고지 의무 위반 시 계약 해지 가능
#   근거 (CoT): 약관에서 고지 의무 위반 시 계약이 해지될 수 있음을 명시하고 있다. 그러나 실수로 일부 정보를 누락할 경우에도 보험금 지급이 거부될 가능성이 있다. 이는 소비자가 고지 의무를 완벽히 이해하지 못해 발생할 수 있다. 동 사례는 관련 법규에서도 고지 의무 위반 시의 처벌...
#   관련 약관/자료: 계약자가 계약 전 알릴 의무를 위반했을 경우 계약이 해지될 수 있음. | 출처: ['이전 약관 전체 요약 제5관', '보험업법 제650조']
# --------------------
# - 요약: 보상금 계산 방식의 모호성
#   근거 (CoT): 원문에서 나머지 금액의 20%에 해당하는 금액이 보상된다고 명시되어 있지만, 이 계산 방식이 소비자들에게 명확하게 이해되지 않을 수 있다. 복잡한 계산 방식으로 인해 예상보다 적은 보험금을 받을 가능성이 있다. ('이전 약관 전체 요약' 제3관 회사가 보상하는 사항 참...
#   관련 약관/자료: 나머지 금액(‘「국민건강보험법」에서 정한 요양급여 또는 「의료급여법」에서 정한 의료급여 중 본인부담금’의 20%에 해당하는 금액) | 출처: ['이전 약관 전체 요약 제3관', '추가 참고 자료 2항']
# --------------------
# - 요약: 통지 의무 불이행 시 불이익
#   근거 (CoT): 약관에서 보험 사유 발생 시 즉시 통지해야 한다고 명시되어 있으나, 많은 소비자들이 이를 놓칠 가능성이 높다. 통지 지연으로 인한 불이익이 발생할 수 있다. ('이전 약관 전체 요약' 제8조 보험금 지급사유 발생의 통지 참고)...
#   관련 약관/자료: 계약자, 피보험자 또는 보험수익자는 제3조에서 정한 보험금 지급사유가 발생한 것을 알았을 때에는 지체 없이 그 사실을 회사에 알려야 합니다. | 출처: ['이전 약관 전체 요약 제8조', '보험업법 제650조']
# --------------------
# - 요약: 보험금 지급 절차의 복잡성
#   근거 (CoT): 약관에서 보험금을 청구하기 위해 다양한 서류를 제출해야 하는데, 이 과정이 복잡하며, 잘못된 서류 제출 시 보험금 지급이 지연될 수 있다. ('이전 약관 전체 요약' 제9조 보험금의 청구 참고)...
#   관련 약관/자료: 보험수익자는 다음의 서류를 제출하고 보험금을 청구하여야 합니다. | 출처: ['이전 약관 전체 요약 제9조', '보험업법 제650조']
# --------------------
# - 요약: 자동대출납입의 이자 부담
#   근거 (CoT): 약관에서 보험료 납입이 어려울 때 자동대출납입이 가능하지만, 이로 인해 추가적으로 이자가 부과된다. 소비자가 이 부분을 이해하지 못해 예상치 못한 이자 부담이 발생할 수 있다. ('이전 약관 전체 요약' 제27조 보험료의 자동대출납입 참고)...
#   관련 약관/자료: 보험료 납입이 곤란한 경우 해약환급금 범위 내에서 자동으로 보험료를 대출하여 납입합니다. 대출이자가 발생합니다. | 출처: ['이전 약관 전체 요약 제27조', '보험업법 제650조']
# --------------------
# - 요약: 약관 설명 의무의 부실
#   근거 (CoT): 약관에서 보험사가 약관의 중요한 내용을 충분히 설명하도록 명시하고 있음에도 불구하고 실제로 모든 내용을 설명하지 않거나 소비자가 이해하기 어려운 경우가 많다. ('이전 약관 전체 요약' 제20조 약관 교부 및 설명 의무 등 참고)...
#   관련 약관/자료: 회사는 계약자가 청약할 때 약관의 중요한 내용을 설명하고, 계약자가 원하는 방법으로 약관 및 청약서를 제공해야 합니다. | 출처: ['이전 약관 전체 요약 제20조', '금융소비자보호법 제16조']
# --------------------
# - 요약: 보상 범위와 면책 범위의 모호성
#   근거 (CoT): 약관에서 보상하지 않는 항목들에 대한 설명이 명확하지 않아 소비자가 이를 이해하기 어려운 경우가 많다. 특히 면책 범위가 불명확하여 소비자가 혼돈할 가능성이 있다. ('이전 약관 전체 요약' 제3관 회사가 보상하지 않는 사항 참고)...
#   관련 약관/자료: 회사가 보상하지 않는 사항은 보장종목별로 다음과 같습니다. | 출처: ['이전 약관 전체 요약 제3관', '추가 참고 자료 3항']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 10/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 71 ---
#
#
# ===== [전체 약관 분석] 청크 11/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "계약자 또는 보험수익자가 변경내용을 알리지 않은 경우에는 계약자 또는 보험수익자가 회사에 알린 최종 주소 또는 연락처로 등기우편 등...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 주소 변경 통지 의무 불이행 시 불이익
#   근거 (CoT): 약관 제12조는 소비자가 주소나 연락처 변경 시 이를 지체 없이 보험사에 통지해야 한다고 명시. 그러나 소비자가 이를 통지하지 않을 경우 최종 주소로 발송된 우편물이 도달된 것으로 간주함. 이로 인해 중요한 안내를 받지 못해 불이익을 당할 가능성 있음. 추가 참고 자료...
#   관련 약관/자료: 계약자 또는 보험수익자가 변경내용을 알리지 않은 경우에는 계약자 또는 보험수익자가 회사에 알린 최종 주소 또는 연락처로 등기우편 등 우편물에 대한 기록이 남는 방법을 통하여 회사가 알린사항은 일반적으로 도달에 필요한 기간이 지난 때에 계약자 또는 보험수익자에게 도달된 것으로 봅니다. | 출처: ['금감원 분쟁사례집 2023 p.45']
# --------------------
# - 요약: 건강보험심사평가원의 진료비확인 요청 동의 요청
#   근거 (CoT): 약관 제10항은 보험사가 필요 시 진료비 확인 절차를 요청할 수 있으며, 동의하지 않으면 보험금 지급이 지연될 수 있음을 명시. 그러나 소비자가 이를 이해하지 못하고 동의하지 않을 경우 발생 가능한 문제를 고려함. 추가 참고 자료에서는 '금감원 분쟁사례집 2020 p....
#   관련 약관/자료: 계약자, 피보험자 또는 보험수익자에게 건강보험심사평가원의 진료비확인요청제도를 활용할 수 있도록 동의해 줄 것을 요청할 수 있으며, 진료비확인요청제도를 활용할 경우 회사는 이를 활용한 사례를 집적하고 먼저 유사 사례가 있는지를 확인하고 이용합니다. | 출처: ['금감원 분쟁사례집 2020 p.37']
# --------------------
# - 요약: 보험료 납입 지연 시 해지 위기
#   근거 (CoT): 약관 제26조는 제2회 이후 보험료를 납입기일까지 납입하지 않으면 계약이 해지될 수 있음을 명시. 추가 참고 자료로 '보험업법 제28조'와 '금감원 분쟁사례집 2019 p.29'에서 유사 사례가 다뤄짐....
#   관련 약관/자료: 계약자는 제2회부터의 보험료를 납입기일까지 납입해야 합니다. 영수증은 회사가 발행합니다. | 출처: ['보험업법 제28조', '금감원 분쟁사례집 2019 p.29']
# --------------------
# - 요약: 자동갱신 시 보험료 인상 관련 정보 부족
#   근거 (CoT): 약관 제47조에서는 자동갱신 조건을 명시하고 있으나, 제48조와 제52조에 갱신 보험료 변동 가능성을 명확히 안내하지 않음. 추가 참고 자료로 '보험업법 제5장'과 '금감원 분쟁사례집 2021 p.54'에서 유사 사례가 존재함....
#   관련 약관/자료: 갱신계약 보험료는 갱신일 현재의 보험요율 제도를 반영하여 계산하며, 나이 증가, 기초율 변동 등에 따라 보험료가 변동될 수 있습니다. | 출처: ['보험업법 제5장', '금감원 분쟁사례집 2021 p.54']
# --------------------
# - 요약: 상해보험계약 후 알릴 의무의 불명확성
#   근거 (CoT): 약관 제15조는 보험 기간 중 피보험자에게 직업과 관련된 변화가 발생하면 지체 없이 회사에 알리도록 요구. 이를 알리지 않으면 변경된 위험에 대한 보험금을 지급받지 못하거나 보험료가 증가될 수 있음. '보험업법 제3장'과 '금감원 분쟁사례집 2022 p.37'에서 유사...
#   관련 약관/자료: 계약자 또는 피보험자는 보험기간 중에 피보험자에게 다음 각 호의 변경이 발생한 경우에는 우편, 전화, 방문 등의 방법으로 지체없이 회사에 알려야 합니다. | 출처: ['보험업법 제3장', '금감원 분쟁사례집 2022 p.37']
# --------------------
# - 요약: 다수보험 비례보상 문제
#   근거 (CoT): 약관 제9관에서는 다수보험의 비례보상을 명시. 그러나 실질적으로 소비자가 이해하기 어려운 절차와 계산 방식이 문제. 추가 참고 자료에서 유사한 사례는 '보험업법 제4장'과 '금감원 분쟁사례집 2021 p.67'에 나옴....
#   관련 약관/자료: 다수보험 가입으로 인해 비례보상된 경우 그 사유 및 개인 혹은 단체 실손 중지제도와 신청방법 등 | 출처: ['보험업법 제4장', '금감원 분쟁사례집 2021 p.67']
# --------------------
# - 요약: 보험금 받을 방법 변경 시 모호한 표현
#   근거 (CoT): 약관 제11조에서는 보험금을 나누어서 받거나 일시적으로 받는 방법을 안내. 단, 나누어 받을 경우 계산 방식에 대한 명확한 설명이 부족하여 소비자가 혼란을 겪을 수 있음. '금감원 분쟁사례집 2022 p.19'의 유사 사례가 이를 뒷받침....
#   관련 약관/자료: 계약자(보험금 지급사유 발생 후에는 보험수익자를 말합니다)는 회사의 사업방법서에서 정한 바에 따라 보험금의 전부 또는 일부에 대하여 나누어 지급받거나 일시에 지급받는 방법으로 변경할 수 있습니다. | 출처: ['금감원 분쟁사례집 2022 p.19']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 11/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 78 ---
#
#
# ===== [전체 약관 분석] 청크 12/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "위험의 증가", "근거_및_추론과정": "약관 원문에서 '위험의 증가'라는 표현이 자주 사용되지만, 구체적으로 어떤 상황을 의미하는...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 용어의 모호성 및 다의성
#   근거 (CoT): 약관 원문에서 '위험의 증가'라는 표현이 자주 사용되지만, 구체적으로 어떤 상황을 의미하는지 명확한 정의가 없습니다. '위험이 증가된 경우'라는 문구는 해석의 여지가 많아 소비자들이 이를 정확히 인지하지 못할 수 있습니다. 이는 [이전 약관 전체 요약]의 '보통약관 제...
#   관련 약관/자료: 위험의 증가 | 출처: ['이전 약관 전체 요약', '삼성화재 기본형 실손의료보험 약관']
# --------------------
# - 요약: <제1항 각 호의 변경사실을 회사에 알리지 않았을 경우>의 이해 어려움
#   근거 (CoT): 소비자가 자신의 직업 또는 직무 변경을 보험사에 알리지 않았을 경우, 보험금이 삭감되거나 지급되지 않는다는 내용이 포함되어 있습니다. 그러나 이러한 변경 사항을 소비자가 명확히 인지하고 즉시 보고해야 하는 중요성에 대해서는 명확한 안내가 부족합니다. 이는 소비자가 자주...
#   관련 약관/자료: 제1항 각 호의 변경사실을 회사에 알리지 않았을 경우 | 출처: ['이전 약관 전체 요약']
# --------------------
# - 요약: 보험금 계산 방식의 복잡성
#   근거 (CoT): 비례 보상 방식이 적용될 때, 소비자가 이해하기 어려운 계산 방식으로 인해 실제 보험금이 예상보다 훨씬 적게 지급될 수 있습니다. 예시된 계산식을 보아도, 일반 소비자들이 이를 복잡하게 느껴 이해하지 못하고 보험금을 과소 청구하게 될 가능성이 있습니다. 이는 [추가 참...
#   관련 약관/자료: 고객이 수령하는 상해사망 보험금 = 1억원 × (0.3 ÷ 0.5) = 6천만원 | 출처: ['추가 참고 자료: 금감원 분쟁사례집 2023 p.45']
# --------------------
# - 요약: 계약자의 잘못된 통지로 인한 보험금 삭감
#   근거 (CoT): 약관에서는 계약자가 고지 의무를 다하지 않았을 때, 보험사는 보험금을 삭감해서 지급할 수 있다고 명시하고 있습니다. 이는 소비자가 사업이나 직무 변경 등의 상황을 제때 보고하지 않아 발생할 수 있는 불이익입니다. [이전 약관 전체 요약]의 '제5관 계약자의 계약 전 알...
#   관련 약관/자료: 계약자 또는 피보험자가 고의 또는 중대한 과실로 제1항 각 호의 변경사실을 회사에 알리지 않았을 경우 | 출처: ['이전 약관 전체 요약']
# --------------------
# - 요약: 위험의 증가에 따른 보험료 증액의 통지 문제
#   근거 (CoT): 약관에서는 위험 증가에 따른 보험료 증액 사실을 소비자에게 통지하도록 되어 있지만, 이 절차가 정확히 수행되지 않았을 때 발생할 문제점이 있습니다. 통지가 지연되거나 누락되어 소비자가 보험료를 제대로 납입하지 못하면, 보험금 지급 시 불이익을 당할 수 있습니다. 이는 ...
#   관련 약관/자료: 위험의 증가로 보험료를 더 내야 할 경우 회사가 청구한 추가보험료 | 출처: ['추가 참고 자료: 삼성화재 기본형 실손의료보험 약관']
# --------------------
# - 요약: 계약 해지의 모호한 기준
#   근거 (CoT): 약관에서 계약 해지의 조건이 명확히 정의되지 않아, 보험사가 이를 악용하여 의심스러운 사유로 계약을 해지할 수 있습니다. 이는 소비자가 예상하지 못한 상황에서 불이익을 당할 수 있는 큰 문제입니다. [추가 참고 자료]에서 '계약자의 임의해지'에 대한 법규와 비교해 보면...
#   관련 약관/자료: 보험금 지급사유의 발생 여부에 관계없이 그 사실을 안 날부터 1개월 이내에 이 계약을 해지할 수 있습니다. | 출처: ['추가 참고 자료: 보험계약자가 알아야 할 법규']
# --------------------
# - 요약: 계약 부활(효력회복)의 복잡성
#   근거 (CoT): 약관에서 계약 해지 후 다시 부활 청약을 위해 많은 서류와 절차가 필요한 경우, 소비자가 이를 제대로 이해하지 못하고 절차를 완료하지 못할 수 있습니다. [이전 약관 전체 요약]의 '제29조 보험료의 납입이 연체되어 해지된 계약의 부활' 내용을 참고했을 때, 복잡한 절...
#   관련 약관/자료: 보험료의 납입을 연체하여 해지된 계약의 부활 | 출처: ['이전 약관 전체 요약']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 12/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 85 ---
#
#
# ===== [전체 약관 분석] 청크 13/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "특정 질병 또는 특정 신체 부위를 보장에서 제외하는 방법을 말합니다.", "근거_및_추론과정": "약관에서 '일부보장 제외 조건'에...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 선택한 보장 제외 항목의 모호함
#   근거 (CoT): 약관에서 '일부보장 제외 조건'에 대한 설명은 모호하다. 특히, '특정 질병 또는 특정 신체 부위를 보장에서 제외'한다는 표현은 해석의 여지가 크다. 이는 [삼성화재 기본형 실손의료보험 약관]의 제18조(2항) 및 '용어풀이' 내용을 근거로 하며, '일부보장 제외(부담...
#   관련 약관/자료: 특정 질병 또는 특정 신체 부위를 보장에서 제외하는 방법을 말합니다. | 출처: ['삼성화재 기본형 실손의료보험 약관 p.32']
# --------------------
# - 요약: 청약 철회 절차의 복잡성
#   근거 (CoT): 약관 제19조(청약의 철회)에 해당하는 조항을 살펴보면, 청약의 철회는 서면, 전자우편, 휴대전화 문자메시지 등을 통해 가능하지만, 이 과정을 따라야 하는 소비자는 복잡한 절차를 이행해야 한다. 계약자가 이 절차를 정확히 이해하기 어렵거나 놓칠 가능성을 예상하였다....
#   관련 약관/자료: 서면, 전자우편, 휴대전화 문자메시지 또는 이에 준하는 전자적 의사표시(이하 ‘서면 등’이라 합니다)로 철회의사를 표시 | 출처: ['삼성화재 기본형 실손의료보험 약관 p.34']
# --------------------
# - 요약: 보험금 삭감 기준의 불명확성
#   근거 (CoT): 약관 제18조(용어 정의)에서 '보험금 삭감'에 대한 내용을 보면, '미리 정해진 비율로 보험금을 감액하여 지급하는 방법'이라고만 되어 있다. 이 비율과 그 이유가 명확히 제시되지 않은 점을 지적하며 불명확성 문제를 예상하였다....
#   관련 약관/자료: 미리 정해진 비율로 보험금을 감액하여 지급하는 방법을 말합니다. | 출처: ['삼성화재 기본형 실손의료보험 약관 p.33']
# --------------------
# - 요약: 청약 철회 불가 상황의 불명확함
#   근거 (CoT): 제19조(청약의 철회)에서 청약 철회가 불가능한 경우를 명시하고 있지만, '회사가 건강상태 진단을 지원하는 계약'이라는 표현은 소비자가 쉽게 오해할 수 있는 여지가 크다. 이는 청약 시 철회가 불가능한 계약임을 명확히 안내해야 하는 필요성을 예상하였다....
#   관련 약관/자료: 회사가 건강상태 진단을 지원하는 계약 | 출처: ['삼성화재 기본형 실손의료보험 약관 p.32']
# --------------------
# - 요약: 계약자 통지 없이 보험금 삭감
#   근거 (CoT): 제18조(보험금 삭감) 조항을 보면 보험금 삭감에 대한 상세한 기준이 명시되지 않으며, 사전에 계약자에게 이에 대한 충분한 설명이 제공되지 않는 점을 문제로 삼았다. 이를 통해 삭감된 금액에 대한 사전 통지가 부족함을 지적하였다....
#   관련 약관/자료: 보험 가입 후 일정기간 내에 보험사고가 발생할 경우 미리 정해진 비율로 보험금을 감액하여 지급하는 방법을 말합니다. | 출처: ['삼성화재 기본형 실손의료보험 약관 p.33']
# --------------------
# - 요약: 상급 병실료 차액 관련 모호한 조건
#   근거 (CoT): 비급여 실손의료비 특별약관 제3조에서 상급병실료 차액 보상 조건이 명확히 설명되지 않으며, 특정 상황에서 이를 어떻게 입증할지 모호한 점을 지적함. 이를 통해 소비자가 보상이 거절될 가능성을 예상하였다....
#   관련 약관/자료: 상급병실료 차액: 비급여 병실료의 50% 보상(1일 10만원 한도) | 출처: ['삼성화재 기본형 실손의료보험 약관 p.45']
# --------------------
# - 요약: 자동갱신시 보험료 인상 통지의 모호함
#   근거 (CoT): 자동갱신에 대한 통지는 제11관 자동갱신에 관한 사항의 제48조(갱신계약 약관)의 내용을 근거로 하였으며, 구체적인 통지 방법과 실제 이행 여부에 관해 모호한 부분을 지적함. 이로 인해 소비자가 제대로 이해할 수 없는 상황을 예상하였다....
#   관련 약관/자료: 보험기간 종료 15일 전까지 계약자에게 통지합니다. | 출처: ['삼성화재 기본형 실손의료보험 약관 p.52']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 13/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 92 ---
#
#
# ===== [전체 약관 분석] 청크 14/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "④ 제3항에도 불구하고 전화를 이용하여 계약을 체결하는 경우 다음의 각 호의 어느 하나를 충족하는 때에는 자필서명을 생략할 수 있으...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 자필서명 대신 음성녹음 활용 시 발생 가능한 문제
#   근거 (CoT): 분석 대상 약관 원문 텍스트에서 전화를 통한 계약 체결 시 자필서명을 생략하고 음성녹음으로 대체할 수 있다고 명시되어 있습니다. 하지만 음성녹음의 경우 계약자가 내용을 충분히 이해하지 못하거나, 녹음 파일이 손실될 경우 계약의 유효성 문제나 분쟁 발생 시 불리한 상황이...
#   관련 약관/자료: ④ 제3항에도 불구하고 전화를 이용하여 계약을 체결하는 경우 다음의 각 호의 어느 하나를 충족하는 때에는 자필서명을 생략할 수 있으며, 제2항의 규정에 따른 음성녹음 내용을 문서화한 확인서를 계약자에게 드림으로써 계약자 보관용 청약서를 전달한 것으로 봅니다. | 출처: ['금감원 분쟁사례집 2023 p.45']
# --------------------
# - 요약: 갱신보험료 상승율의 모호성
#   근거 (CoT): 약관 요약서에서 '갱신 시 연령 증가, 위험률 변동 등으로 보험료가 인상될 수 있음'이라고 명시되어 있으나, 보험료 인상의 구체적인 기준이나 한도가 명확히 제시되지 않았습니다. 이로 인해, 소비자는 갱신 시 예기치 못한 큰 폭의 보험료 인상을 경험할 수 있습니다....
#   관련 약관/자료: 갱신 시 연령 증가, 위험률 변동 등으로 보험료가 인상될 수 있음. | 출처: []
# --------------------
# - 요약: 보험계약대출이율 복리 적용의 불명확성
#   근거 (CoT): 제22조에서 보험료 반환 시 보험계약대출이율을 복리로 계산한다고 명시되어 있으나, 복리 계산 시 적용되는 이율이나 구체적인 계산 방식이 명시되지 않아 혼란을 초래할 가능성이 큽니다. 이는 '보험업법 제6조'와 관련된 분쟁 사례에서도 유사한 문제가 제기된 바 있습니다....
#   관련 약관/자료: 보험료를 받은 기간에 대하여 이 계약의 보험계약대출이율을 연단위 복리로 계산한 금액을 더하여 지급합니다. | 출처: ['보험업법 제6조']
# --------------------
# - 요약: 계약자 통지 의무의 불명확성
#   근거 (CoT): 분석 대상 약관 원문에서는 계약자가 중요한 변경 사항을 회사에 통지해야 한다고 명시되어 있지만, 구체적인 통지 방법이나 시점이 명확하지 않습니다. '금감원 분쟁사례집 2023 p.67'에서도 유사한 문제로 분쟁이 발생한 사례를 볼 수 있습니다....
#   관련 약관/자료: 계약자는 회사의 승낙을 받아 다음의 사항을 변경할 수 있습니다. | 출처: ['금감원 분쟁사례집 2023 p.67']
# --------------------
# - 요약: 계약 성립일과 보험료 납부일의 충돌 가능성
#   근거 (CoT): 약관 원문에서 제1회 보험료를 자동이체나 신용카드로 납입하는 경우에, 자동이체 신청 또는 신용카드 승인에 필요한 정보를 제공한 날을 보험료 납부일로 간주하지만, 이로 인한 시차로 보험금 지급에 어려움이 발생할 수 있습니다. '삼성화재 기본형 실손의료보험 약관' 제25조...
#   관련 약관/자료: 제1회 보험료를 자동이체 또는 신용카드로 납입하는 경우, 자동이체 신청 및 신용카드 승인에 필요한 정보를 제공한 때를 제1회 보험료를 받은 때로 합니다. | 출처: ['삼성화재 기본형 실손의료보험 약관 제25조']
# --------------------
# - 요약: 보상 및 면책 불명확성
#   근거 (CoT): 보통약관 제4조에서 상해와 질병의 보상되지 않는 사항을 명시하고 있지만, 구체적인 안내가 부족하여 소비자가 어떤 상황에서 보상이 되지 않는지를 명확히 이해하기 어렵습니다. '금감원 분쟁사례집 2023 p.45'에서도 유사한 문제가 발생한 사례를 확인할 수 있습니다....
#   관련 약관/자료: 회사가 보상하지 않는 사항은 보장종목별로 다음과 같습니다. | 출처: ['금감원 분쟁사례집 2023 p.45']
# --------------------
# - 요약: 해약환급금 미지급 가능성
#   근거 (CoT): 제35조에서 해약환급금의 계산 방법을 명시하지 않았으며, 구체적인 해약환급금 산출 기준이 명확하지 않아 소비자가 환급금의 정확한 금액을 예측할 수 없습니다. 이는 '삼성화재 기본형 실손의료보험 약관'에서 제35조에 관련된 내용을 참고할 수 있습니다....
#   관련 약관/자료: 해약환급금은 보험료 및 해약환급금 산출방법서에 따라 계산합니다. | 출처: ['삼성화재 기본형 실손의료보험 약관 제35조']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 14/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 99 ---
#
#
# ===== [전체 약관 분석] 청크 15/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "보장개시일을 계약일로 봅니다.", "근거_및_추론과정": "약관 원문에서 보장개시일을 '계약일로 본다'고 정의하고 있으나, '계약이...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 보장개시일과 계약일의 혼동 가능성
#   근거 (CoT): 약관 원문에서 보장개시일을 '계약일로 본다'고 정의하고 있으나, '계약이 성립되고 제1회 보험료를 받은 날'이라고도 설명하여 소비자가 보장개시일과 계약일을 혼동할 가능성이 높음 (삼성화재 약관, 메리츠 약관 참조). 또한, 참고 자료에 따르면 이런 혼동으로 인해 분쟁이...
#   관련 약관/자료: 보장개시일을 계약일로 봅니다. | 출처: ['금감원 분쟁사례집 2023 p.23', '메리츠 약관 제1조']
# --------------------
# - 요약: 자동대출납입 이자 부담
#   근거 (CoT): 자동대출납입에 따른 이자를 '회사가 정하는 이율'로 규정하여 이자율 변동에 따른 부담이 예상됨. 메리츠 약관에서는 자동대출 이율을 명확히 제시하지 않아 소비자가 이자 부담을 미리 인지하기 어려움. 관련 법규에서는 이러한 이율 공개가 중요하다고 명시되어 있음 (금융소비자...
#   관련 약관/자료: 회사가 별도로 정하는 이율을 적용하여 계산 | 출처: ['금융소비자 보호법 제15조', '메리츠 약관 제29조']
# --------------------
# - 요약: 납입기일 관련 모호성
#   근거 (CoT): 납입기일을 '제2회부터의 보험료를 납입하기로 한 날'이라고 정의하여 구체적인 날짜를 명시하지 않아 혼란이 생길 수 있음 (삼성화재, 메리츠 약관 참조). 참고 자료에서도 이런 모호성으로 인한 소비자 불이익 사례가 다수 보고됨 (금감원 분쟁사례집 2023 p.67)....
#   관련 약관/자료: 납입기일: 계약자가 제2회 이후의 보험료를 납입하기로 한 날 | 출처: ['금감원 분쟁사례집 2023 p.67', '메리츠 약관 제27조']
# --------------------
# - 요약: 보험계약대출이율 변경사항 미명시
#   근거 (CoT): 약관에서 보험계약대출이율이 변경될 수 있다고 명시하고 있으나, 구체적인 변경 기준이나 통지 방법을 안내하지 않아 소비자가 변경된 이율을 인지하지 못할 가능성이 있음 (메리츠 약관, 금융소비자 보호법 참조)....
#   관련 약관/자료: 변경된 시점부터 변경된 이율을 적용합니다. | 출처: ['금융소비자 보호법 제15조', '메리츠 약관 제27조']
# --------------------
# - 요약: 납입최고(독촉) 기간의 모호성
#   근거 (CoT): 약관에서 납입최고(독촉) 기간을 '14일(보험기간이 1년 미만인 경우 7일)'로 정의하고 있으나, 영업일 계산의 명확한 기준을 제시하지 않아 소비자가 해석에 어려움을 겪을 수 있음. 금감원 사례에서도 이런 모호성으로 인한 혼란 사례가 보고됨 (금감원 분쟁사례집 2023...
#   관련 약관/자료: 납입최고(독촉)기간: 14일(보험기간이 1년 미만인 경우 7일) | 출처: ['금감원 분쟁사례집 2023 p.45', '메리츠 약관 제28조']
# --------------------
# - 요약: 갱신 시 보장 개시일의 모호성
#   근거 (CoT): 갱신 시 보장 개시일을 '기존 계약에 의한 보장이 종료하는 때부터 적용'한다고 명시하고 있으나, 구체적인 시점이 불명확하여 갱신과 보장 개시의 정확한 시점을 혼동할 가능성이 있음 (삼성화재 약관, 금감원 분쟁사례집 참조)....
#   관련 약관/자료: 갱신 시 보장은 기존 계약에 의한 보장이 종료하는 때부터 적용합니다. | 출처: ['금감원 분쟁사례집 2023 p.32', '삼성화재 약관 제19조']
# --------------------
# - 요약: 고지의무 위반 시 불이익 미명시
#   근거 (CoT): 약관에서 고지의무 위반 시 '회사가 보장을 하지 않을 수 있다'고만 명시하고, 구체적인 불이익 내용을 설명하지 않아 소비자가 이를 인지하기 어렵고, 위반 시 발생할 수 있는 불이익을 예측하기 어려움 (메리츠 약관, 삼성화재 약관 참조)....
#   관련 약관/자료: 회사가 보장을 하지 않을 수 있는 경우 | 출처: ['금융소비자 보호법 제16조', '메리츠 약관 제13조']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 15/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 106 ---
#
#
# ===== [전체 약관 분석] 청크 16/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "재가입 절차 ... 직전 계약과 동일한 조건으로 자동 연장됩니다.", "근거_및_추론과정": "약관 원문에서 '재가입 절차'가 충분...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 계약 재갱신의 모호한 기재로 인한 소비자 혼란
#   근거 (CoT): 약관 원문에서 '재가입 절차'가 충분히 명확하지 않으며, 그로 인해 소비자가 재갱신 요건을 혼동할 가능성이 높음. 특히 '직전 계약과 동일한 조건으로 자동 연장' 등 이야기가 일관되지 않음. [추가 참고 자료: 무배당 메리츠 통합건강보험약관]과 비교하여 이점이 더욱 명...
#   관련 약관/자료: 재가입 절차 ... 직전 계약과 동일한 조건으로 자동 연장됩니다. | 출처: ['무배당 메리츠 통합건강보험약관, p.25']
# --------------------
# - 요약: 계약 부활 시 높은 이자율로 인한 소비자 부담
#   근거 (CoT): 약관 원문에서 부활 시 필요한 이자율이 '평균공시이율에 1%를 더한 이율'로 명시되어 있어 이율 상승 시 소비자가 큰 부담을 느낄 가능성이 있음. [추가 참고 자료: 무배당 메리츠 통합건강보험약관]에도 비슷한 사례 존재....
#   관련 약관/자료: 평균공시이율에 1%를 더한 이율 | 출처: ['무배당 메리츠 통합건강보험약관, p.30']
# --------------------
# - 요약: 고지 의무 위반 시 효력 회복 문제
#   근거 (CoT): 약관 원문에서 고지 의무 위반 시 계약 효력 회복에 대한 제한이 명시되어 있음. 이는 소비자가 부득이하게 정보를 누락했을 경우 큰 불이익을 당할 수 있는 여지를 남김. [추가 참고 자료: 무배당 내Mom같은 어린이보험 약관]에도 유사 사례 존재....
#   관련 약관/자료: 계약자 또는 피보험자가 최초계약 청약시 고지 의무를 위반한 경우 | 출처: ['무배당 내Mom같은 어린이보험 약관, p.45']
# --------------------
# - 요약: 계약자 명의 변경의 통지 지연 문제
#   근거 (CoT): 약관 원문에서 통지가 늦는 경우에 대한 언급이 있으며, 이는 통지 지연이 발생할 경우 소비자가 불이익을 당할 수 있는 여지를 남김. [추가 참고 자료: 메리츠 통합건강보험 약관]에도 유사한 사례가 나타남....
#   관련 약관/자료: 회사의 통지가 7일이 지나 보험수익자에게 도달하고 | 출처: ['메리츠 통합건강보험 약관, p.52']
# --------------------
# - 요약: 해지 시 환급금 계산 문제
#   근거 (CoT): 약관 원문에서 해약환급금 계산이 '보험료 및 해약환급금 산출방법서'에 따라 이루어진다고 명시되어 있는데, 이는 소비자가 쉽게 이해할 수 없는 내용일 가능성이 큼. [추가 참고 자료: 유사 보험 약관]과도 비교하여 유사한 문제 확인됨....
#   관련 약관/자료: 해약환급금은 보험료 및 해약환급금 산출방법서에 따라 계산합니다. | 출처: ['기타 유사 보험 약관, p.34']
# --------------------
# - 요약: 계약 해지 관련 피보험자 보호 부족
#   근거 (CoT): 약관 원문에서 계약 해지가 너무 쉽게 이루어질 수 있는 조건이 많으며, 이는 피보험자가 적절한 보호를 받지 못할 가능성을 높임. [추가 참고 자료: 금감원 분쟁사례집]과 비교하여 이런 사례가 실제로 발생한 바 있음....
#   관련 약관/자료: 다음과 같은 사실이 있을 경우 ... 계약을 해지할 수 있습니다. | 출처: ['금감원 분쟁사례집, 2023 p.45']
# --------------------
# - 요약: 강제집행 시 계약자 동의 절차 미비
#   근거 (CoT): 약관 원문에서 강제집행 시 계약자 동의 절차가 명확히 규정되지 않은 점이 문제로 지적될 수 있음. [추가 참고 자료: 무배당 내Mom같은 어린이보험 약관]과 비교해도 유사한 사례 존재....
#   관련 약관/자료: 회사는 ... 계약자의 동의를 받아 ... 계약의 특별부활(효력회복)을 청약할 수 있음을 보험수익자에게 통지하여야 합니다. | 출처: ['무배당 내Mom같은 어린이보험 약관, p.60']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 16/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 113 ---
#
#
# ===== [전체 약관 분석] 청크 17/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "해약환급금의 지급사유가 발생한 경우 계약자는 회사에 해약환급금을 청구하여야 하며, 회사는 청구를 접수한 날부터 3영업일 이내에 해약...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 계약 해지 후 해약환급금 지급 지연
#   근거 (CoT): 약관 제35조 제2항에 따르면 해약환급금은 청구를 접수한 날부터 3영업일 이내에 지급되어야 합니다. 그러나 이 조항은 단지 '3영업일 이내'라고만 명시되어 있어, 실제 처리 과정에서 지연이 발생할 가능성이 있습니다. '3영업일 이내'가 월요일부터 금요일만 해당되는지, ...
#   관련 약관/자료: 해약환급금의 지급사유가 발생한 경우 계약자는 회사에 해약환급금을 청구하여야 하며, 회사는 청구를 접수한 날부터 3영업일 이내에 해약환급금을 지급합니다. | 출처: ['금감원 분쟁사례집 2023 p.45']
# --------------------
# - 요약: 파산 시 추가적인 계약 해지 불능
#   근거 (CoT): 약관 제34조 제2항에 따르면 회사 파산 후 3개월이 지나면 해지하지 않은 계약의 효력이 상실됩니다. 이는 소비자가 파산 사실을 인지하지 못한 경우, 3개월 이내에 해지하지 못해 계약의 효력 상실 위험에 처할 수 있음을 의미합니다. 법령상 파산 통지 의무나 절차가 명확...
#   관련 약관/자료: 제1항에 따라 해지하지 않은 계약은 파산선고 후 3개월이 지나면 그 효력을 잃습니다. | 출처: ['보험계약법 제13조']
# --------------------
# - 요약: 보험계약대출 사실 통지의 모호성
#   근거 (CoT): 약관 제36조 제5항에 따르면 회사는 보험수익자에게 보험계약대출 사실을 통지할 수 있다고만 명시되어 있습니다. 이 조항은 '통지할 수 있다'는 표현 때문에 통지가 선택사항으로 보일 수 있으며, 소비자가 대출 사실을 알지 못해 불이익을 당할 가능성이 높습니다. [추가 참...
#   관련 약관/자료: 회사는 보험수익자에게 보험계약대출 사실을 통지할 수 있습니다. | 출처: ['소비자 기본법 제23조']
# --------------------
# - 요약: 계약자적립액의 불명확한 산출 방식
#   근거 (CoT): 약관 제35조 제1항에서 계약자적립액에 대해 언급하지만, 구체적인 산출 방식이나 기준이 명확히 제공되지 않았습니다. 이는 소비자가 자신의 계약자적립액을 계산하는 데 어려움을 겪고, 예상보다 적은 금액을 받을 가능성을 높입니다. [추가 참고 자료]에서는 계약자적립액 계산...
#   관련 약관/자료: 장래의 보험금, 해약환급금 등을 지급하기 위하여 계약자가 납입한 보험료 중 일정액을 회사가 적립해 둔 금액 | 출처: ['금감원 소비자불만 사례집 2022 p.143']
# --------------------
# - 요약: 소멸시효 완성 조건의 모호성
#   근거 (CoT): 제42조에 따르면 소멸시효는 '3년간 행사하지 않으면 소멸'한다고 명시되어 있지만, 소멸시효의 시작 시점이 언제인지, 어떤 경우에 소멸시효가 중단되는지에 대한 명확한 설명이 부족합니다. 이는 소비자가 중요한 기한을 놓치게 하거나 오해하게 할 가능성을 높입니다 (출처: ...
#   관련 약관/자료: 보험금 청구권, 만기환급금 청구권, 보험료 반환청구권, 해약환급금 청구권, 계약자적립액 및 미경과보험료 반환청구권 및 배당금청구권은 3년간 행사하지 않으면 소멸시효가 완성됩니다. | 출처: ['약관 규제법 제6조']
# --------------------
# - 요약: 청약철회 기간의 불명확성
#   근거 (CoT): 제19조에 따르면 청약철회 기간은 '보험증권을 받은 날부터 15일 또는 청약일로부터 30일 중 먼저 도래하는 날까지'라고 명시되어 있습니다. 그러나 '먼저 도래하는 날'의 의미가 명확하지 않아 소비자가 철회할 수 있는 시간을 놓치는 경우가 발생할 수 있습니다 (출처: ...
#   관련 약관/자료: 청약철회 기간: 보험증권을 받은 날부터 15일 또는 청약일로부터 30일 중 먼저 도래하는 날까지 | 출처: ['보험업법 제96조']
# --------------------
# - 요약: 다수보험 비례분담액 계산의 복잡성
#   근거 (CoT): 제38조에 따르면 다수보험의 경우 각 계약의 비례분담액을 계산하여 지급한다고 명시되어 있지만, 비례분담액 계산 방식이 매우 복잡하여 일반 소비자가 이해하기 어렵습니다. 이는 소비자가 불리한 조건으로 보상받을 가능성을 높입니다 (출처: 금감원 분쟁사례집 2022 p.22...
#   관련 약관/자료: 각 계약별 비례분담액 = (각 계약의 보장대상의료비 중 최고액 - 각 계약의 피보험자부담 공제금액 중 최소액) × 각 계약별 보장책임액 / 각 계약별 보장책임액을 합한 금액 | 출처: ['금감원 분쟁사례집 2022 p.220']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 17/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 120 ---
#
#
# ===== [전체 약관 분석] 청크 18/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "갱신계약의 보험료는 매년 최대 25% 범위(나이의 증가로 인한 보험료 증감분은 제외) 내에서 인상 또는 인하될 수 있습니다.", "...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 갱신 시 보험료 인상 가능성
#   근거 (CoT): 분석 대상 약관 원문 텍스트의 제52조와 제48조에서 보험료 변동 가능성에 대해 명시하고 있습니다. 갱신 시 보험료가 나이 증가와 기초율 변동 등으로 인하여 인상될 수 있으며, 매년 최대 25% 범위 내에서 인상/인하될 수 있다는 내용이 있습니다. 이는 소비자가 갱신 ...
#   관련 약관/자료: 갱신계약의 보험료는 매년 최대 25% 범위(나이의 증가로 인한 보험료 증감분은 제외) 내에서 인상 또는 인하될 수 있습니다. | 출처: ['분석 대상 약관 원문 텍스트 제52조, 제48조', "이전 약관 전체 요약 '갱신시 보험료 인상 가능성'"]
# --------------------
# - 요약: 약관 문구의 모호성
#   근거 (CoT): 관련 약관 원문 텍스트의 '현저하게 불공정한 합의' 정의는 매우 포괄적이고 주관적입니다. 보험회사가 이를 자의적으로 해석할 여지가 있습니다. 추가 참고 자료에서 언급한 '현저하게 공정을 잃은 합의'의 정의 역시 구체적이지 않아서 갈등이 발생할 수 있습니다....
#   관련 약관/자료: '현저하게 불공정한 합의' - 회사가 보험수익자의 경제적·신체적·정신적인 어려움, 경솔함, 경험 부족 등을 이용하여 동일·유사 사례에 비추어 보험수익자에게 매우 불합리하게 합의를 하는 것 | 출처: ['분석 대상 약관 원문 텍스트 제45조', "추가 참고 자료 '현저하게 공정을 잃은 합의' 정의"]
# --------------------
# - 요약: 개인정보 제공 동의 절차 문제
#   근거 (CoT): 관련 약관 원문 텍스트에서 계약자 동의를 받아 다른 보험회사 및 보험관련 단체에 개인정보를 제공할 수 있다고 명시하고 있으나, 동의서의 세부 내용에 대한 구체적인 설명이 부족합니다. 개인정보 보호법에 따르면, 개인정보를 수집할 때 수집목적과 내용을 명확히 고지해야 합니...
#   관련 약관/자료: 회사는 이 계약의 체결, 유지, 보험금 지급 등을 위하여 위 관계 법령에 따라 계약자 및 피보험자의 동의를 받아 다른 보험회사 및 보험관련단체 등에 개인정보를 제공할 수 있습니다. | 출처: ['분석 대상 약관 원문 텍스트 제46조', '개인정보 보호법']
# --------------------
# - 요약: 자동갱신 절차의 불명확성
#   근거 (CoT): 관련 약관 원문 텍스트에서는 갱신계약이 자동갱신된다고 명시하였으나, 보험기간 종료 15일 전까지 알리는 절차가 명확하지 않습니다. 추가 참고 자료에서 설명된 '설명서 교부 및 보험안내자료 등의 효력' 관련 내용을 참고하면, 이러한 절차가 명확하지 않아 소비자에게 불이익...
#   관련 약관/자료: N/A | 출처: ['분석 대상 약관 원문 텍스트 제47조, 제48조', "추가 참고 자료 '설명서 교부 및 보험안내자료 등의 효력'"]
# --------------------
# - 요약: 손해배상 청구 기간의 모호성
#   근거 (CoT): 약관에서 손해배상 청구 가능 기간을 '최초계약일부터 5년 이내'로 정했지만, 소비자가 이를 명확히 인식하지 못하면 청구 기한을 놓칠 가능성이 큽니다. 추가 참고 자료에서도 보험금 청구 시 소멸 시효 등이 문제될 수 있다는 사례들이 언급되고 있음....
#   관련 약관/자료: N/A | 출처: ['분석 대상 약관 원문 텍스트 제45조', '추가 참고 자료 금감원 분쟁 사례집']
# --------------------
# - 요약: 보상 제외 항목의 불명확성
#   근거 (CoT): 보상하지 않는 사항은 약관에서 명확히 규정되어야 하는 부분임에도 불구하고, 특정 부분들은 모호하거나 범위가 명확하지 않은 경우가 많습니다. 추가 참고 자료의 예시로, 특정 경우에는 보상하지 않는다면서도 예외 규정이나 특별한 경우를 명확히 설명하지 않는 부분들이 발견됨....
#   관련 약관/자료: N/A | 출처: ['분석 대상 약관 원문 텍스트 제3관 제4조', "추가 참고 자료 '보험 분쟁 사례'"]
# --------------------
# - 요약: 다수보험 가입 시 불이익 가능성
#   근거 (CoT): 약관에서 다수보험에 대한 정의나 범위가 구체적이지 않아, 소비자가 실수로 여러 실손의료보험에 가입하는 경우 불이익을 당할 위험이 큽니다. 추가 참고 자료에서도 다수보험 관련 분쟁 사례가 자주 발생하는 부분임이 확인됩니다....
#   관련 약관/자료: N/A | 출처: ['분석 대상 약관 원문 텍스트 제45조', '추가 참고 자료 금감원 분쟁 사례']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 18/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 127 ---
#
#
# ===== [전체 약관 분석] 청크 19/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ...
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 응급의료기관 외 의료비 보상 불명확
#   근거 (CoT): 약관 원문에서 '응급의료기관'으로 지정되지 않은 기관은 보상 대상에서 제외한다는 내용이 포함되었습니다 (분석 대상 약관 원문 텍스트). 동시에, [응급의료에 관한 법률 시행규칙]에 따라 비응급의료기관에서 신고 없이 응급환자를 치료할 수 있지만, 이에 대한 보상 여부는 ...
#   관련 약관/자료: '응급의료기관으로 지정받지 아니한 의료기관이 응급의료시설을 설치ㆍ운영하려면 보건복지부령으로 정하는 시설ㆍ인력 등을 갖추어 신고하여야 한다.' | 출처: ['응급의료에 관한 법률 시행규칙 제2조']
# --------------------
# - 요약: 보장 종목의 정의가 불명확
#   근거 (CoT): 약관 원문에서 상해와 질병의 정의가 명확히 구분되지 않음으로 인해, 이들 중 어느 상황에 해당되는지를 혼동할 가능성이 높습니다. 이는 기본 약관의 '제1관 일반사항 및 용어의 정의' 부분에서 상해와 질병의 구분이 명료하지 않음을 통해 확인할 수 있습니다....
#   관련 약관/자료: '상해로 인해 의료기관에 입원 또는 통원하여 치료를 받은 경우와 질병으로 인해 입원 또는 통원하여 치료를 받은 경우 보상.' | 출처: ['삼성화재 기본형 실손의료보험 약관 제1관']
# --------------------
# - 요약: 고지 의무 위반시 불이익 조항 이해 어려움
#   근거 (CoT): 약관에서 고지 의무에 대한 명확한 설명 없이 단순히 고지 의무 위반 시 불이익을 언급하는 정도에 그쳐있습니다. 이는 '제5관 계약자의 계약 전 알릴 의무 등'에서 주요 병력 고지의 범위가 구체적이지 않음을 통해 확인할 수 있습니다....
#   관련 약관/자료: '계약자가 중요한 사실을 알리지 않으면, 계약이 해지될 수 있으며, 보험금도 지급되지 않을 수 있습니다.' | 출처: ['삼성화재 기본형 실손의료보험 약관 제5관']
# --------------------
# - 요약: 보험금 지급 절차 복잡성
#   근거 (CoT): 약관의 '제4관 보험금의 지급'에서 요구되는 서류와 절차가 복잡하고 명확하지 않아서 소비자가 혼동할 수 있습니다. 이는 실제 보험금 청구 과정에서 발생할 수 있는 현실적 장애요소로 작용할 수 있습니다....
#   관련 약관/자료: '보험금 청구 시 필요 서류: 진단서, 영수증, 그 밖의 관련 증빙서류 등.' | 출처: ['삼성화재 기본형 실손의료보험 약관 제4관']
# --------------------
# - 요약: 자동갱신과 보험료 인상 가능성
#   근거 (CoT): 약관의 '제11관 자동갱신에 관한 사항' 및 '제12관 재가입에 관한 사항'에서 자동갱신 시 보험료 인상 가능성에 대해 언급하고 있지만, 그 폭이나 구체적인 계산 방식이 명확히 설명되지 않아 소비자가 이를 충분히 이해하기 어렵습니다....
#   관련 약관/자료: '자동갱신 시 보험료 인상 가능성 있음.' | 출처: ['삼성화재 기본형 실손의료보험 약관 제11관, 제12관']
# --------------------
# - 요약: 특정 치료 보상 제외 항목의 모호성
#   근거 (CoT): 약관의 '제3관 회사가 보상하지 않는 사항'에서 '정당한 이유 없이'라는 표현이 포함되어 있지만, 그 의미가 명확히 정의되지 않아서 여러 가지 해석이 가능하게 됩니다. 이는 꼭 필요한 치료임에도 불구하고 회사가 보상을 거부할 가능성을 높입니다....
#   관련 약관/자료: '정당한 이유 없이 의사의 지시를 따르지 않음.' | 출처: ['삼성화재 기본형 실손의료보험 약관 제3관']
# --------------------
# - 요약: 치과 및 한방 치료 보장 제외 범위의 미비
#   근거 (CoT): 약관에서 '치과 및 한방 비급여는 보상되지 않음'이라고 언급하지만, 구체적으로 어떤 범주의 치료가 해당되는지 명확히 정의되지 않았습니다. 이는 소비자가 어떤 치료가 정확히 보상 되는지를 혼동할 가능성을 증가시킵니다....
#   관련 약관/자료: '임신, 출산 관련 사항, 건강검진, 예방접종, 치과 및 한방 비급여, 자동차보험 또는 산재보험에서 보상받는 의료비 등은 보상되지 않음.' | 출처: ['삼성화재 기본형 실손의료보험 약관']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 58/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 406 ---
#
#
# ===== [전체 약관 분석] 청크 59/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "국외에 체류하는 경우 보험급여를 하지 아니한다.", "근거_및_추론과정": "약관 원문 '국외에 체류하는 경우 보험급여를 하지 아니...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 보험급여 제한의 모호성
#   근거 (CoT): 약관 원문 '국외에 체류하는 경우 보험급여를 하지 아니한다'는 표현은 국외 체류 중 발생한 질병이 국내 귀국 후에도 영향을 미칠 수 있다는 점에서 모호성이 존재합니다. 이 조항이 '국외 체류 중 발생한 질병' 또는 '국내 귀국 후 발생한 질병'을 명확히 구분하지 않아,...
#   관련 약관/자료: 국외에 체류하는 경우 보험급여를 하지 아니한다. | 출처: 금감원 분쟁사례집 2023 p.22
# --------------------
# - 요약: 분할납부 승인 후 연체 시 위험
#   근거 (CoT): 약관 원문 '분할납부 승인된 보험료를 5회 이상 내지 아니한 경우에는 그러하지 아니하다'는 조건은 정당한 사유의 판단 기준이 모호합니다. 이로 인해 소비자가 경제적 어려움 등의 이유로 납입을 못 했을 때, 보험사가 이를 정당한 사유로 인정하지 않으면 보험급여가 중지될 ...
#   관련 약관/자료: 정당한 사유 없이 5회 이상 그 승인된 보험료를 내지 아니한 경우에는 그러하지 아니하다. | 출처: 약관 규제법 제6조
# --------------------
# - 요약: 급여제한기간 중 보험급여 인정 조건의 복잡성
#   근거 (CoT): 약관 원문 '납부기한 이내에 체납된 보험료를 완납한 경우'와 '분할납부 승인을 받은 체납보험료를 1회 이상 낸 경우' 등의 조건은 복잡하여 소비자가 혼동할 수 있습니다. 추가 참고 자료 '금융소비자 보호에 관한 법률'에 따르면, 금융상품의 계약 조건이 복잡하면 소비자가...
#   관련 약관/자료: 납부기한 이내에 체납된 보험료를 완납한 경우 ... 분할납부 승인을 받은 체납보험료를 1회 이상 낸 경우 | 출처: 금융소비자 보호에 관한 법률
# --------------------
# - 요약: 소득월액보험료 체납 시 개인 귀책 사유 불명확
#   근거 (CoT): 약관 원문 '소득월액보험료를 체납한 경우에는 그 체납에 대하여 직장가입자 본인에게 귀책사유가 있는 경우에 한하여'라는 표현은 개인 귀책 사유의 판단 기준이 모호하여 분쟁의 여지가 큽니다. 추가 참고 자료 '금감원 분쟁사례집 2023 p.35'에 따르면, 유사한 분쟁 사...
#   관련 약관/자료: 소득월액보험료를 체납한 경우에는 그 체납에 대하여 직장가입자 본인에게 귀책사유가 있는 경우에 한하여 | 출처: 금감원 분쟁사례집 2023 p.35
# --------------------
# - 요약: 장기 미납으로 인한 보험급여 제한 기간의 불명확성
#   근거 (CoT): 약관 원문 '대통령령으로 정하는 기간 이상 보험료를 체납한 경우'는 그 기간이 명확하게 정의되어 있지 않아 소비자가 이해하기 어렵습니다. 추가 참고 자료 '보험업감독규정 제120조'에서는 명확한 고지의무가 강조되고 있으며, 이러한 모호성은 소비자 불이익을 초래할 수 있...
#   관련 약관/자료: 대통령령으로 정하는 기간 이상 보험료를 체납한 경우 | 출처: 보험업감독규정 제120조
# --------------------
# - 요약: 보험료 체납 기준의 불명확성
#   근거 (CoT): 약관 원문 '보험료의 총체납횟수'는 정의가 불명확하여, 소비자가 실제로 얼마나 보험료를 납입해야 하는지 혼동할 수 있습니다. 참고 자료 '금융소비자 보호에 관한 법률'에 따라, 이러한 모호성은 소비자에게 불리한 영향을 미칠 수 있습니다....
#   관련 약관/자료: 보험료의 총체납횟수 | 출처: 금융소비자 보호에 관한 법률
# --------------------
# - 요약: 보험료 납입 승인 후 추가 연체 시 보험급여 중지 기준 모호성
#   근거 (CoT): 약관 원문 '분할납부 승인을 받은 사람이 정당한 사유 없이 5회 이상 그 승인된 보험료를 내지 아니한 경우'는 '정당한 사유'의 판단 기준이 모호합니다. 추가 참고 자료 '금감원 분쟁사례집 2023 p.48'에서 유사한 사례가 논의된 바 있으며, 이로 인해 소비자는 보...
#   관련 약관/자료: 정당한 사유 없이 5회 이상 그 승인된 보험료를 내지 아니한 경우에는 그러하지 아니하다. | 출처: 금감원 분쟁사례집 2023 p.48
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 59/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 413 ---
#
#
# ===== [전체 약관 분석] 청크 60/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "\"상해로 인해 의료기관에 입원 또는 통원하여 치료를 받은 경우\", \"질병으로 인해 의료기관에 입원 또는 통원하여 치료를 받은 ...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 상해와 질병의 중복 정의 모호성
#   근거 (CoT): 제1관, 제2조에서 '상해'와 '질병'의 정의가 각각 제시되어 있으나, 이를 구분하는 기준이 명확하지 않다. 만약 사고로 인한 질병이 발생한 경우, 이를 상해로 간주할지 질병으로 간주할지 모호할 수 있다. [이전 약관 전체 요약]과 [법규26] 금융소비자 보호에 관한 ...
#   관련 약관/자료: "상해로 인해 의료기관에 입원 또는 통원하여 치료를 받은 경우", "질병으로 인해 의료기관에 입원 또는 통원하여 치료를 받은 경우" | 출처: ['이전 약관 전체 요약', '금융소비자 보호에 관한 법률 제2조']
# --------------------
# - 요약: 특정 질병 치료 비급여 제외 불명확성
#   근거 (CoT): 제3관 제4조에서 '정신 및 행동장애'는 명시적으로 질병급여에서 제외되지만, 비급여 실손의료비 특별약관에서 '정신 및 행동장애' 항목이 명시되어 있지 않다. 이는 비급여 치료에 대해 소비자가 혼동할 가능성을 제공한다. [법규26] 금융소비자 보호에 관한 법률 제19조의...
#   관련 약관/자료: "정신 및 행동장애 관련 의료비는 보상하지 않는다" | 출처: ['이전 약관 전체 요약', '금융소비자 보호에 관한 법률 제19조']
# --------------------
# - 요약: 고지 의무 위반 시 소비자 부담
#   근거 (CoT): 제5관 계약자의 계약 전 알릴 의무 등 조항에서 고지 의무를 자세히 설명하지만, 경미한 증상이나 상태도 포함되는지 명확하지 않다. [추가 참고 자료]에서 금융소비자 보호 법률 제19조 관련 설명 의무와 비교해 볼 때, 불명확한 고지 의무는 소비자에게 큰 부담을 줄 수 ...
#   관련 약관/자료: "고지 의무를 다하지 않은 경우, 보험사는 계약을 해지하거나 보험금을 지급하지 않을 수 있다" | 출처: ['금융소비자 보호에 관한 법률 제19조']
# --------------------
# - 요약: 자동대출납입 이자의 불명확성
#   근거 (CoT): 제27조 자동대출납입 조항에서 대출 이자에 대한 언급이 있지만, 그 이율이나 상세 조건이 명확하지 않다. 이는 소비자에게 중요한 재정적 부담을 줄 수 있다. [이전 약관 전체 요약]과 [법규26] 금융소비자 보호에 관한 법률 제19조에 따른 설명 의무를 고려할 때, 불...
#   관련 약관/자료: "자동대출납입 기간 동안 이자가 발생하며, 이자 계산은 회사가 정한 이율로 한다" | 출처: ['이전 약관 전체 요약', '금융소비자 보호에 관한 법률 제19조']
# --------------------
# - 요약: 탈락 조건 모호성
#   근거 (CoT): 제3관 제2조의 상해급여와 질병급여 내용에서 '정당한 이유 없이 의사의 지시를 따르지 않은 경우'라는 조건이 모호하게 표현되어 있다. 이는 소비자에게 불명확한 기준을 제공해 보험금 지급 거부 사유가 될 수 있다. [추가 참고 자료] 금융소비자 보호 법률 제19조의 설명...
#   관련 약관/자료: "정당한 이유 없이 입원 또는 통원 기간 중 의사의 지시를 따르지 않은 경우" | 출처: ['금융소비자 보호에 관한 법률 제19조']
# --------------------
# - 요약: 계약 무효 사유의 상세 불충분
#   근거 (CoT): 제21조 계약 무효 항목에서 '피보험자의 나이가 계약 조건에 미달하거나 초과된 경우'에 대해 언급하나, 구체적인 나이 기준이나 조건에 대한 설명이 부족하다. 이는 소비자가 상황을 충분히 이해하지 못하고 계약이 부당하게 무효화되는 상황을 초래할 수 있다. [이전 약관 전...
#   관련 약관/자료: "피보험자의 나이가 계약 조건에 미달하거나 초과된 경우 계약은 무효가 된다" | 출처: ['금융소비자 보호에 관한 법률 제19조']
# --------------------
# - 요약: 환급금 지급 절차의 복잡성
#   근거 (CoT): 제35조 해약환급금 조항에서 '해약환급금 청구: 청구를 접수한 날부터 3영업일 이내에 지급'이라고 명시돼 있지만, 청구 절차나 필요한 서류에 대한 설명이 부족하다. 이는 소비자가 필요한 절차를 정확히 이행하지 못해 환급금을 받지 못하는 상황을 초래할 수 있다. [법규2...
#   관련 약관/자료: "해약환급금 청구: 청구를 접수한 날부터 3영업일 이내에 지급" | 출처: ['금융소비자 보호에 관한 법률 제19조']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 60/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 420 ---
#
#
# ===== [전체 약관 분석] 청크 61/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "일반금융소비자가 청약의 철회의사를 표시하기 위하여 서면등을 발송하고...", "근거_및_추론과정": "약관 원문에서 '서면등'이라는...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 청약 철회 절차 불명확성
#   근거 (CoT): 약관 원문에서 '서면등'이라는 표현(A)이 사용되었으나, 구체적인 방법이 명시되지 않음. 따라서 금융상품판매업자가 이메일 등의 방식으로 접수되지 않았다고 주장하면 소비자는 입증하기 어려움(B). 이로 인해 청약 철회 절차가 불명확하다는 문제(C)가 예상됨(D)....
#   관련 약관/자료: 일반금융소비자가 청약의 철회의사를 표시하기 위하여 서면등을 발송하고... | 출처: ['금융소비자 보호에 관한 법률 시행령 제13조']
# --------------------
# - 요약: 보상하지 않는 사항의 모호성
#   근거 (CoT): 약관 원문에서 '고의로 자신을 해친 경우'라는 표현(A)이 모호하여, 어떤 상황이 여기에 속하는지 명확하지 않음. 관련 법규(B)에서는 천재 또는 비천재의 상황을 다루나, 자살 시도와 자해 행위 사이의 구분이 복잡함(C). 따라서 소비자가 이를 혼동해 잘못 청구할 가능...
#   관련 약관/자료: 고의로 자신을 해친 경우 | 출처: ["보험소비자연맹 '보험소비자 가이드' p.32", '약관 규제법 제6조']
# --------------------
# - 요약: 보험금 계산 방식의 불명확성
#   근거 (CoT): 약관 원문에서 '대통령령으로 정하는 바에 따라 계산한 금액을 더하여 지급할 것'이라는 표현(A)이 불명확함. 이는 소비자가 반환 지연 기간에 따른 금액을 이해하는 데 어려움을 주며(B), 실제 계산 방법을 명확히 하여 불필요한 분쟁을 최소화할 필요 있음(C). 결과적으...
#   관련 약관/자료: 대통령령으로 정하는 바에 따라 계산한 금액을 더하여 지급할 것 | 출처: ['금융소비자 보호에 관한 법률 시행령 제13조']
# --------------------
# - 요약: 위법계약 해지 절차의 복잡성
#   근거 (CoT): 약관 원문에서 계약 해지 요구 절차의 복잡함(A)이 문제임. 관련 법규(B)에서는 해지 요구서를 제출해야 하지만 필요한 증빙 자료의 명확한 기준이 없어서 소비자가 실질적으로 이를 준비하기 어려움(C). 따라서 소비자는 위법계약 해지를 요구하기 어려울 가능성이 있음(D)...
#   관련 약관/자료: 위반사항을 증명하는 서류를 첨부하여 금융상품직접판매업자 또는 금융상품자문업자에게 제출해야 한다 | 출처: ['금융소비자 보호에 관한 법률 제47조', '금융소비자 보호에 관한 법률 시행령 제38조']
# --------------------
# - 요약: 보장범위의 현실성과 괴리
#   근거 (CoT): 약관 원문에서 비급여 의료비와 상급병실료 차액에 대한 보상(A)의 범위가 현실적이지 않음. 국가에서 조사한 비급여 의료비 비율과 실제 병원비 규모를 고려할 때(B), 소비자가 실제 부담해야 하는 비용이 과도하게 큼(C). 따라서 이는 소비자에게 큰 재정적 부담으로 작용...
#   관련 약관/자료: 상급병실료 차액: 비급여 병실료의 50% 보상(1일 10만원 한도) | 출처: ["금융소비자 보호협회 '실손의료보험 보고서' p.15"]
# --------------------
# - 요약: 고지 의무 강화로 인한 부담 증가
#   근거 (CoT): 약관 원문에서 고지 의무와 관련된 조건(A)이 소비자에게 부담이 큼. 관련 법규(B)에서는 고지 의무를 강조하고 있으나, 이를 모두 준수하기 어려움(C). 따라서 소비자가 실수로 이를 누락하는 경우 계약 해지나 보험금 미지급 문제가 발생할 가능성이 있음(D)....
#   관련 약관/자료: 보험사는 계약자가 고지 의무를 위반한 경우 계약을 해지할 수 있음 | 출처: ['금융소비자 보호에 관한 법률 제19조']
# --------------------
# - 요약: 소비자 안내의 부족으로 이해 어려움
#   근거 (CoT): 약관 원문에서 중요한 내용이 복잡하게 작성되었고(A), 명확한 강조나 요약이 부족함(B). 소비자가 이를 쉽게 이해하지 못해 약관의 중요한 내용을 놓치고(C), 예상치 못한 불이익을 경험할 가능성이 있음(D)....
#   관련 약관/자료: 임신, 출산 관련 사항, 건강검진, 예방접종, 치과 및 한방 비급여, 자동차보험 또는 산재보험에서 보상받는 의료비 등은 보상되지 않음 | 출처: ['약관 규제법 제6조']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 61/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 427 ---
#
#
# ===== [전체 약관 분석] 청크 62/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "금융상품과 연계되거나 제휴된 금융상품 또는 서비스 등을 말한다.", "근거_및_추론과정": "약관 원문에서 '스등(금융상품과 연계되...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 8개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 약관 문구의 모호성
#   근거 (CoT): 약관 원문에서 '스등(금융상품과 연계되거나 제휴된 금융상품 또는 서비스 등을 말한다. 이하 같다)'라는 용어 사용이 명확하지 않음. '금융상품'과 '서비스'라는 단어가 구체적으로 어떤 것들을 포함하는지 모호하여 소비자가 정확히 이해하기 어렵습니다. 이는 소비자가 자신에...
#   관련 약관/자료: 금융상품과 연계되거나 제휴된 금융상품 또는 서비스 등을 말한다. | 출처: ['삼성화재 기본형 실손의료보험 약관']
# --------------------
# - 요약: 보험금 계산 방식의 불명확성
#   근거 (CoT): [분석 대상 약관 원문 텍스트]에서 '해약을 하거나 만기에 이른 경우에 각각 금융소비자에 돌려주어야 하는 금액'에 대해 설명하지만, 산출근거가 불명확함. 이로 인해 소비자가 보험금 청구 시 예상금액과 실제 지급 금액의 차이로 인해 분쟁이 발생할 가능성이 큼. '이미 납...
#   관련 약관/자료: 해약을 하거나 만기에 이른 경우에 각각 금융소비자에 돌려주어야 하는 금액(이하 '환급금'이라 한다) 및 산출근거. 이 경우 그 금액이 이미 납부한 보험료보다 적거나 없을 수 있다는 사실을 함께 설명해야 한다. | 출처: ['삼성화재 기본형 실손의료보험 약관']
# --------------------
# - 요약: 고지 의무 미준수에 따른 불이익
#   근거 (CoT): 약관에서 상법 제651조에 따른 고지의무 및 같은 법 제652조에 따른 통지의무를 명시하고, 이를 위반 시 계약이 해지될 수 있다고 명시. 그러나 이 조항을 소비자가 쉽게 이해하고 준수하도록 설명하는 내용이 부족함. 특히 중요한 의무를 충분히 설명하지 않고, 이를 위반...
#   관련 약관/자료: 일반금융소비자 또는 피보험자가 '상법' 제651조에 따른 고지의무 및 같은 법 제652조에 따른 통지의무를 각각 위반한 경우에 금융상품직접판매업자가 계약을 해지할 수 있다는 사실. | 출처: ['삼성화재 기본형 실손의료보험 약관']
# --------------------
# - 요약: 비급여 항목 보상 불명확성
#   근거 (CoT): [이전 약관 전체 요약]의 '보장종목별 보상내용'에서 비급여 항목에 대해 명확히 정의하고 있음에도 불구하고, 비급여 항목의 구체적인 예시와 보상 여부를 명확히 설명하지 않음. 소비자가 실비보험의 실제 보장 내용을 정확히 알지 못하면, 보험금을 청구할 때 여러 문제를 겪...
#   관련 약관/자료: 3대비급여 치료: 비급여 의료비에서 공제금액을 뺀 금액 보상(연간 350만원 한도). 주사료: 비급여 의료비에서 공제금액을 뺀 금액 보상(연간 250만원 한도). | 출처: ['삼성화재 기본형 실손의료보험 약관']
# --------------------
# - 요약: 법규와의 불일치 가능성
#   근거 (CoT): 특정 문구와 관련 법령이 불일치할 경우 혼란을 야기할 수 있음. 예를 들어, 국가유공자 및 독립유공자의 진료비용 부담 관련 조항은 약관에 명시된 세부 사항(면책 등)과 상충될 가능성이 있음. '국가가 제1항에 따른 진료를 국가나 지방자치단체 외의 의료시설에 위탁할 수 ...
#   관련 약관/자료: 제42조(진료): 국가는 제1항에 따른 진료를 국가나 지방자치단체 외의 의료시설에 위탁할 수 있다. | 출처: ['국가유공자 등 예우 및 지원에 관한 법률']
# --------------------
# - 요약: 보험금 지급 절차 문제
#   근거 (CoT): [분석 대상 약관 원문 텍스트]에서 제시된 설명사항은 소비자가 이해하기 어렵게 복잡하며, 이는 보험금 청구 시 서류 준비 과정에서 문제가 될 수 있음. '청약철회 방법: 전화, 서면, 전자우편, 문자메시지 등'과 같은 표현이 복잡하며, 이는 소비자가 정확한 절차를 이해...
#   관련 약관/자료: 청약철회 방법: 전화, 서면, 전자우편, 문자메시지 등. | 출처: ['삼성화재 기본형 실손의료보험 약관']
# --------------------
# - 요약: 갱신 시 보험료 인상 가능성 고지 부족
#   근거 (CoT): [삼성화재 기본형 실손의료보험 약관 요약]에서 갱신 시 보험료 인상 가능성을 언급하지만, 이는 매우 일반적인 설명에 그치고 있음. 소비자가 구체적으로 얼마나 인상될 수 있는지, 어떤 기준으로 인상될 수 있는지에 대해 명확히 고지하지 않음....
#   관련 약관/자료: 갱신시 보험료 인상 가능성: 갱신 시 연령 증가, 위험률 변동 등으로 보험료가 인상될 수 있음. | 출처: ['삼성화재 기본형 실손의료보험 약관 요약']
# --------------------
# - 요약: 다른 조항과 충돌 가능성
#   근거 (CoT): [분석 대상 약관 원문 텍스트]에서 여러 조건이 상충될 수 있음. 예를 들어, '주된 위험보장사항'과 '부수적인 위험보장사항' 간의 우선순위가 명확히 정의되지 않음. 보험금 지급 시 어떤 항목이 먼저 적용되는지에 대한 기준이 불명확하여 혼란이 발생할 가능성이 큼....
#   관련 약관/자료: 주된 위험보장사항·부수적인 위험보장사항 및 각각의 보험료·보험금. | 출처: ['삼성화재 기본형 실손의료보험 약관']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 8개의 후보 선정. ---
#
# --- 청크 62/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 435 ---
#
#
# ===== [전체 약관 분석] 청크 63/63 문제점 발상 시작 =====
#
# --- [2단계] RAG를 사용한 잠재적 문제점 발상 시작 ---
#
# --- RAG 검색 시작 ---
# RAG 검색 완료. 총 5개의 참고 자료 확보.
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 분석 시작 (1회 반복) =====
#
# ----- [1/1 번째 문제점 발상 시도 중] -----
#
# ===== [2단계] 잠재적 문제점 발상 Self-consistency (RAG 활용) 결과 요약 빈도 =====
# '[{"id": 1, "관련_약관_원문_표현": "의료기관: '의료법 제3조에 의한 종합병원, 병원, 치과병원, 한방병원, 요양병원, 의원, 치과의원, 한의원을 포함'", "근거_및...': 1회
#
# ===== [2단계] Self-consistency 최종 문제점 발상 결과 (RAG 활용) =====
# 총 7개의 문제점 후보 선정 (Self-consistency 기반):
# - 요약: 약관 내 용어 모호성
#   근거 (CoT): 약관 원문에서는 '의료기관'이란 '의료법 제3조에 의한 종합병원, 병원, 치과병원, 한방병원, 요양병원, 의원, 치과의원, 한의원을 포함'한다고 정의. 그러나 소비자가 의료기관의 정의에 포함되지 않는 특정 기관(예: 요양원)을 선택한 경우, 이로 인해 보험 청구가 거절...
#   관련 약관/자료: 의료기관: '의료법 제3조에 의한 종합병원, 병원, 치과병원, 한방병원, 요양병원, 의원, 치과의원, 한의원을 포함' | 출처: ['약관 규제법 제6조']
# --------------------
# - 요약: 보상 제외 조건의 불명확성
#   근거 (CoT): 약관에서 정신 및 행동장애 관련 의료비는 보상하지 않는다고 명시. 그러나 이 범주는 매우 광범위해 정신과 진단의 세부 항목이 다양함에 따라 소비자가 혼란을 겪고 보상이 불가능한 진료인지 쉽게 알 수 없음. 예를 들어 우울증(MDD, F33.0)을 가진 소비자는 보험 청...
#   관련 약관/자료: 정신 및 행동장애(F04∼F99) 관련 의료비 | 출처: ['금감원 분쟁사례집 2023, p.45']
# --------------------
# - 요약: 고지 의무 위반의 불이익
#   근거 (CoT): 약관에서는 계약자가 계약 전 고지의 의무를 적으나, 이러한 고지 내용을 소비자가 명확하게 인지하지 못하거나 알지 못한 상태를 미리 알려야 한다는 규정을 잘못 이해한다면, 나중에 발생한 보험 사고 때 보상을 받지 못하게 될 가능성이 있음....
#   관련 약관/자료: 계약자의 계약 전 알릴 의무 | 출처: ['약관 규제법 제6조', '애니펫 약관 제7조']
# --------------------
# - 요약: 복잡한 보험금 청구 절차
#   근거 (CoT): 약관에서 보험금 청구에 필요한 서류의 양과 종류가 매우 많아 소비자가 이를 모두 준비하기 어렵거나 실수로 하나라도 빠뜨리는 경우, 보험금 청구가 거절될 수 있음. 이러한 복잡한 절차는 특히 고령자나 정보 접근성이 낮은 소비자에게 불리하게 작용할 가능성이 큼....
#   관련 약관/자료: 보험금 청구에 필요한 서류 제출 | 출처: ['금감원 분쟁사례집 2023, p.58']
# --------------------
# - 요약: 자동갱신 시 보험료 인상 가능성
#   근거 (CoT): 약관에서 자동갱신 시 보험료 인상 가능성을 명시하고 있지만, 그 인상될 범위나 구체적인 상승률에 대한 정보가 없어 소비자가 크게 인상된 보험료를 청구받을 가능성이 높음. 특히, 고령화로 인해 보험료가 지속적으로 상승하는 상황에서는 예기치 못한 경제적 부담이 커질 수 있...
#   관련 약관/자료: 갱신 시 연령 증가, 위험률 변동 등으로 보험료가 인상될 수 있음 | 출처: ['약관 규제법 제6조']
# --------------------
# - 요약: 법규와의 불일치
#   근거 (CoT): 약관의 '국가유공자의 유족 또는 가족은 「한국보훈복지의료공단법」 제7조에 따른 보훈병원에서 진료하며' 항목은 국가보훈부장관의 지정에 대한 내용을 구체적으로 설명하지 않음. 이로 인해 유공자 가족이 특정 병원에서 진료를 받고 보험 청구를 하는 경우, 보훈병원의 지정 여부...
#   관련 약관/자료: 국가유공자의 유족 또는 가족은 「한국보훈복지의료공단법」 제7조에 따른 보훈병원에서 진료하며 | 출처: ['독립유공자예우에 관한 법률 제17조', '국가유공자 등 예우 및 지원에 관한 법률 제45조']
# --------------------
# - 요약: 계산 과정의 복잡성
#   근거 (CoT): 약관의 계산 과정이 복잡하여 비급여 의료비 보상 시 연간 한도와 공제금액 계산이 어렵다면, 소비자가 예상 보험금이 실제 지급액보다 적다는 사실을 알게 될 수 있음. 이는 특히 자기부담금 산정이 명확하지 않을 경우 문제가 됨....
#   관련 약관/자료: 비급여 의료비의 연간 보상한도 적용 | 출처: ['금감원 분쟁사례집 2023, p.70']
# --------------------
#
# --- [2단계] 잠재적 문제점 발상 완료. 총 7개의 후보 선정. ---
#
# --- 청크 63/63 문제점 발상 완료. 현재까지 발상된 총 후보 개수: 442 ---

# %%
print("\n\n===== 2단계 최종 결과 (전체 약관 문제점 발상 종합) =====")
print(f"약관 원문 전체 분석 결과, 총 {len(all_problem_candidates_from_chunks)}개의 잠재적 문제점 후보 발상.")
# Out:
# ===== 2단계 최종 결과 (전체 약관 문제점 발상 종합) =====
# 약관 원문 전체 분석 결과, 총 442개의 잠재적 문제점 후보 발상.

# %% [markdown]
# ### gdrive에 step2 폴더 만들어 저장

# %%
# --- Step 2 결과 저장 경로 지정 ---
# Google Drive 내에서 Step 2 결과를 저장할 폴더 경로
# 이 폴더가 없다면 자동으로 생성됩니다.
STEP2_RESULTS_SAVE_DIR = '/content/drive/MyDrive/UNIV./25-1/컴퓨터네트워크/cn_api_project/step2_results' # 예시 경로
# 저장할 파일 이름
STEP2_RESULTS_FILE_NAME = 'problem_candidates.json'
# 최종 저장될 파일 경로
step2_results_save_path = os.path.join(STEP2_RESULTS_SAVE_DIR, STEP2_RESULTS_FILE_NAME)


print("\n--- Step 2 결과 (잠재적 문제점 후보 목록) Google Drive에 저장 시작 ---")

# 저장할 데이터 확인 (all_problem_candidates_from_chunks 변수에 결과가 담겨 있는지)
# run_problem_identification_step 함수 실행 결과를 담았던 변수 이름을 확인하세요.
# 이전 코드에서 all_problem_candidates_from_chunks 변수에 결과가 담겼습니다.
data_to_save = all_problem_candidates_from_chunks if 'problem_candidates_result' in locals() and all_problem_candidates_from_chunks else []


if data_to_save:
    try:
        # 저장 디렉토리가 없다면 생성
        if not os.path.exists(STEP2_RESULTS_SAVE_DIR):
            os.makedirs(STEP2_RESULTS_SAVE_DIR, exist_ok=True)
            print(f"저장 디렉토리 생성: '{STEP2_RESULTS_SAVE_DIR}'")
        else:
            print(f"저장 디렉토리 확인: '{STEP2_RESULTS_SAVE_DIR}'")

        # JSON 파일로 저장
        # 'w' 모드는 쓰기 모드, encoding='utf-8'은 한글 깨짐 방지
        # json.dump() 함수로 파이썬 객체를 JSON 문자열로 변환하여 파일에 씁니다.
        # ensure_ascii=False는 한글이 유니코드 이스케이프(\uXXXX)되지 않도록 합니다.
        # indent=2는 JSON 파일을 들여쓰기하여 사람이 읽기 쉽게 만듭니다. (파일 크기는 커짐)
        with open(step2_results_save_path, 'w', encoding='utf-8') as f:
            json.dump(data_to_save, f, ensure_ascii=False, indent=2)

        print(f"--- Step 2 결과 JSON 파일 저장 완료! ---")
        print(f"파일 경로: '{step2_results_save_path}'")
        print(f"저장된 문제점 후보 개수: {len(data_to_save)}")

    except Exception as e:
        print(f"!!! 오류: Step 2 결과 저장 중 오류 발생 !!!")
        print(f"오류 내용: {e}")
        print(f"경로 확인: '{step2_results_save_path}' 경로에 쓸 수 있는지, Google Drive 마운트 상태가 올바른지 확인하세요.")

else:
    print("!!! Step 2 분석 결과 (문제점 후보 목록)가 비어있습니다. 저장할 내용이 없습니다. !!!")
    print("이전 분석 실행 단계에서 오류가 발생했는지 확인해주세요.")

print("\n--- Step 2 노트북 마무리 코드 실행 완료 ---")
# Out:
# --- Step 2 결과 (잠재적 문제점 후보 목록) Google Drive에 저장 시작 ---
# 저장 디렉토리 생성: '/content/drive/MyDrive/UNIV./25-1/컴퓨터네트워크/cn_api_project/step2_results'
# --- Step 2 결과 JSON 파일 저장 완료! ---
# 파일 경로: '/content/drive/MyDrive/UNIV./25-1/컴퓨터네트워크/cn_api_project/step2_results/problem_candidates.json'
# 저장된 문제점 후보 개수: 442
#
# --- Step 2 노트북 마무리 코드 실행 완료 ---
